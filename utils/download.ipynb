# %% [markdown]
# # Inside Airbnb Australia

# %%
import gzip
import os
import shutil
from datetime import datetime

import requests
from dateutil.relativedelta import relativedelta

# %% [markdown]
# ## Define Date Range

# %% [markdown]
# Calculate all the dates since `2012-08-01` (Airbnb launched in Australia) till today in the format `YYYY-MM-DD`.

# %%
# set the start_date to the day when Airbnb launched in Australia
start_date = datetime(2012, 8, 1)
end_date = datetime.today()  # last time updated on 2024-08-17

# calculate all the dates between start_date and end_date
dates = []  
while start_date <= end_date:
    dates.append(start_date.strftime('%Y-%m-%d'))
    start_date += relativedelta(days=1)  # set interval to 1 day

print(dates)
# Out:
# ['2012-08-01', '2012-08-02', '2012-08-03', '2012-08-04', '2012-08-05', '2012-08-06', '2012-08-07', '2012-08-08', '2012-08-09', '2012-08-10', '2012-08-11', '2012-08-12', '2012-08-13', '2012-08-14', '2012-08-15', '2012-08-16', '2012-08-17', '2012-08-18', '2012-08-19', '2012-08-20', '2012-08-21', '2012-08-22', '2012-08-23', '2012-08-24', '2012-08-25', '2012-08-26', '2012-08-27', '2012-08-28', '2012-08-29', '2012-08-30', '2012-08-31', '2012-09-01', '2012-09-02', '2012-09-03', '2012-09-04', '2012-09-05', '2012-09-06', '2012-09-07', '2012-09-08', '2012-09-09', '2012-09-10', '2012-09-11', '2012-09-12', '2012-09-13', '2012-09-14', '2012-09-15', '2012-09-16', '2012-09-17', '2012-09-18', '2012-09-19', '2012-09-20', '2012-09-21', '2012-09-22', '2012-09-23', '2012-09-24', '2012-09-25', '2012-09-26', '2012-09-27', '2012-09-28', '2012-09-29', '2012-09-30', '2012-10-01', '2012-10-02', '2012-10-03', '2012-10-04', '2012-10-05', '2012-10-06', '2012-10-07', '2012-10-08', '2012-10-09', '2012-10-10', '2012-10-11', '2012-10-12', '2012-10-13', '2012-10-14', '2012-10-15', '2012-10-16', '2012-10-17', '2012-10-18', '2012-10-19', '2012-10-20', '2012-10-21', '2012-10-22', '2012-10-23', '2012-10-24', '2012-10-25', '2012-10-26', '2012-10-27', '2012-10-28', '2012-10-29', '2012-10-30', '2012-10-31', '2012-11-01', '2012-11-02', '2012-11-03', '2012-11-04', '2012-11-05', '2012-11-06', '2012-11-07', '2012-11-08', '2012-11-09', '2012-11-10', '2012-11-11', '2012-11-12', '2012-11-13', '2012-11-14', '2012-11-15', '2012-11-16', '2012-11-17', '2012-11-18', '2012-11-19', '2012-11-20', '2012-11-21', '2012-11-22', '2012-11-23', '2012-11-24', '2012-11-25', '2012-11-26', '2012-11-27', '2012-11-28', '2012-11-29', '2012-11-30', '2012-12-01', '2012-12-02', '2012-12-03', '2012-12-04', '2012-12-05', '2012-12-06', '2012-12-07', '2012-12-08', '2012-12-09', '2012-12-10', '2012-12-11', '2012-12-12', '2012-12-13', '2012-12-14', '2012-12-15', '2012-12-16', '2012-12-17', '2012-12-18', '2012-12-19', '2012-12-20', '2012-12-21', '2012-12-22', '2012-12-23', '2012-12-24', '2012-12-25', '2012-12-26', '2012-12-27', '2012-12-28', '2012-12-29', '2012-12-30', '2012-12-31', '2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04', '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08', '2013-01-09', '2013-01-10', '2013-01-11', '2013-01-12', '2013-01-13', '2013-01-14', '2013-01-15', '2013-01-16', '2013-01-17', '2013-01-18', '2013-01-19', '2013-01-20', '2013-01-21', '2013-01-22', '2013-01-23', '2013-01-24', '2013-01-25', '2013-01-26', '2013-01-27', '2013-01-28', '2013-01-29', '2013-01-30', '2013-01-31', '2013-02-01', '2013-02-02', '2013-02-03', '2013-02-04', '2013-02-05', '2013-02-06', '2013-02-07', '2013-02-08', '2013-02-09', '2013-02-10', '2013-02-11', '2013-02-12', '2013-02-13', '2013-02-14', '2013-02-15', '2013-02-16', '2013-02-17', '2013-02-18', '2013-02-19', '2013-02-20', '2013-02-21', '2013-02-22', '2013-02-23', '2013-02-24', '2013-02-25', '2013-02-26', '2013-02-27', '2013-02-28', '2013-03-01', '2013-03-02', '2013-03-03', '2013-03-04', '2013-03-05', '2013-03-06', '2013-03-07', '2013-03-08', '2013-03-09', '2013-03-10', '2013-03-11', '2013-03-12', '2013-03-13', '2013-03-14', '2013-03-15', '2013-03-16', '2013-03-17', '2013-03-18', '2013-03-19', '2013-03-20', '2013-03-21', '2013-03-22', '2013-03-23', '2013-03-24', '2013-03-25', '2013-03-26', '2013-03-27', '2013-03-28', '2013-03-29', '2013-03-30', '2013-03-31', '2013-04-01', '2013-04-02', '2013-04-03', '2013-04-04', '2013-04-05', '2013-04-06', '2013-04-07', '2013-04-08', '2013-04-09', '2013-04-10', '2013-04-11', '2013-04-12', '2013-04-13', '2013-04-14', '2013-04-15', '2013-04-16', '2013-04-17', '2013-04-18', '2013-04-19', '2013-04-20', '2013-04-21', '2013-04-22', '2013-04-23', '2013-04-24', '2013-04-25', '2013-04-26', '2013-04-27', '2013-04-28', '2013-04-29', '2013-04-30', '2013-05-01', '2013-05-02', '2013-05-03', '2013-05-04', '2013-05-05', '2013-05-06', '2013-05-07', '2013-05-08', '2013-05-09', '2013-05-10', '2013-05-11', '2013-05-12', '2013-05- ...

# %% [markdown]
# ## Define URLs

# %% [markdown]
# DO NOT CHANGE THE FOLLOWING CODE BLOCK.

# %%
# We want to download from the following example URLs:
# listings.csv.gz: https://data.insideairbnb.com/australia/sa/barossa-valley/2024-03-29/data/listings.csv.gz
# reviews.csv.gz: https://data.insideairbnb.com/australia/sa/barossa-valley/2024-03-29/data/reviews.csv.gz

prefix = 'https://data.insideairbnb.com/australia'

locations = ['sa/barossa-valley', 
             'vic/barwon-south-west-vic', 
             'qld/brisbane',
             'vic/melbourne',
             'nsw/mid-north-coast',
             'vic/mornington-peninsula',
             'nsw/northern-rivers',
             'qld/sunshine-coast',
             'nsw/sydney',
             'tas/tasmania',
             'wa/western-australia']

affix_listings = 'data/listings.csv.gz'
affix_reviews = 'data/reviews.csv.gz'

format = '.csv.gz'

# %% [markdown]
# ## Download from All Locations from All Dates

# %%
save_root = '/Users/yifan/Documents/GitHub/datasets/Inside-Airbnb-Australia/Inside-Airbnb-Australia/all'
if not os.path.exists(save_root):
    os.makedirs(save_root, exist_ok=True)


for location in locations:
    for date in dates:
        for affix in [affix_listings, affix_reviews]:
            url = f'{prefix}/{location}/{date}/{affix}'
            res = requests.get(url)
            # download .csv.gz files
            name = f'{location.split('/')[-1]}_{date}_{affix.split('/')[-1]}'
            with open(os.path.join(save_root, name), 'wb') as f:
                f.write(res.content)
            print(f"Downloaded {name}")
            # try to unzip, delete invalid file if failed
            try: 
                with gzip.open(os.path.join(save_root, name), 'rb') as f_in, \
                    open(os.path.join(save_root, name[:-3]), 'wb') as f_out:
                    shutil.copyfileobj(f_in, f_out)
                print(f"Unzipped to {name[:-3]}")
            except gzip.BadGzipFile:
                print(f"Removed invalid {name} and {name[:-3]}")
                os.remove(os.path.join(save_root, name))
                os.remove(os.path.join(save_root, name[:-3]))
# Out:
# Downloaded barossa-valley_2012-08-01_listings.csv.gz
# Removed invalid barossa-valley_2012-08-01_listings.csv.gz and barossa-valley_2012-08-01_listings.csv
# Downloaded barossa-valley_2012-08-01_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-01_reviews.csv.gz and barossa-valley_2012-08-01_reviews.csv
# Downloaded barossa-valley_2012-08-02_listings.csv.gz
# Removed invalid barossa-valley_2012-08-02_listings.csv.gz and barossa-valley_2012-08-02_listings.csv
# Downloaded barossa-valley_2012-08-02_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-02_reviews.csv.gz and barossa-valley_2012-08-02_reviews.csv
# Downloaded barossa-valley_2012-08-03_listings.csv.gz
# Removed invalid barossa-valley_2012-08-03_listings.csv.gz and barossa-valley_2012-08-03_listings.csv
# Downloaded barossa-valley_2012-08-03_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-03_reviews.csv.gz and barossa-valley_2012-08-03_reviews.csv
# Downloaded barossa-valley_2012-08-04_listings.csv.gz
# Removed invalid barossa-valley_2012-08-04_listings.csv.gz and barossa-valley_2012-08-04_listings.csv
# Downloaded barossa-valley_2012-08-04_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-04_reviews.csv.gz and barossa-valley_2012-08-04_reviews.csv
# Downloaded barossa-valley_2012-08-05_listings.csv.gz
# Removed invalid barossa-valley_2012-08-05_listings.csv.gz and barossa-valley_2012-08-05_listings.csv
# Downloaded barossa-valley_2012-08-05_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-05_reviews.csv.gz and barossa-valley_2012-08-05_reviews.csv
# Downloaded barossa-valley_2012-08-06_listings.csv.gz
# Removed invalid barossa-valley_2012-08-06_listings.csv.gz and barossa-valley_2012-08-06_listings.csv
# Downloaded barossa-valley_2012-08-06_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-06_reviews.csv.gz and barossa-valley_2012-08-06_reviews.csv
# Downloaded barossa-valley_2012-08-07_listings.csv.gz
# Removed invalid barossa-valley_2012-08-07_listings.csv.gz and barossa-valley_2012-08-07_listings.csv
# Downloaded barossa-valley_2012-08-07_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-07_reviews.csv.gz and barossa-valley_2012-08-07_reviews.csv
# Downloaded barossa-valley_2012-08-08_listings.csv.gz
# Removed invalid barossa-valley_2012-08-08_listings.csv.gz and barossa-valley_2012-08-08_listings.csv
# Downloaded barossa-valley_2012-08-08_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-08_reviews.csv.gz and barossa-valley_2012-08-08_reviews.csv
# Downloaded barossa-valley_2012-08-09_listings.csv.gz
# Removed invalid barossa-valley_2012-08-09_listings.csv.gz and barossa-valley_2012-08-09_listings.csv
# Downloaded barossa-valley_2012-08-09_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-09_reviews.csv.gz and barossa-valley_2012-08-09_reviews.csv
# Downloaded barossa-valley_2012-08-10_listings.csv.gz
# Removed invalid barossa-valley_2012-08-10_listings.csv.gz and barossa-valley_2012-08-10_listings.csv
# Downloaded barossa-valley_2012-08-10_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-10_reviews.csv.gz and barossa-valley_2012-08-10_reviews.csv
# Downloaded barossa-valley_2012-08-11_listings.csv.gz
# Removed invalid barossa-valley_2012-08-11_listings.csv.gz and barossa-valley_2012-08-11_listings.csv
# Downloaded barossa-valley_2012-08-11_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-11_reviews.csv.gz and barossa-valley_2012-08-11_reviews.csv
# Downloaded barossa-valley_2012-08-12_listings.csv.gz
# Removed invalid barossa-valley_2012-08-12_listings.csv.gz and barossa-valley_2012-08-12_listings.csv
# Downloaded barossa-valley_2012-08-12_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-12_reviews.csv.gz and barossa-valley_2012-08-12_reviews.csv
# Downloaded barossa-valley_2012-08-13_listings.csv.gz
# Removed invalid barossa-valley_2012-08-13_listings.csv.gz and barossa-valley_2012-08-13_listings.csv
# Downloaded barossa-valley_2012-08-13_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-13_reviews.csv.gz and barossa-valley_2012-08-13_reviews.csv
# Downloaded barossa-valley_2012-08-14_listings.csv.gz
# Removed invalid barossa-valley_2012-08-14_listings.csv.gz and barossa-valley_2012-08-14_listings.csv
# Downloaded barossa-valley_2012-08-14_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-14_reviews.csv.gz and barossa-valley_2012-08-14_reviews.csv
# Downloaded barossa-valley_2012-08-15_listings.csv.gz
# Removed invalid barossa-valley_2012-08-15_listings.csv.gz and barossa-valley_2012-08-15_listings.csv
# Downloaded barossa-valley_2012-08-15_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-15_reviews.csv.gz and barossa-valley_2012-08-15_reviews.csv
# Downloaded barossa-valley_2012-08-16_listings.csv.gz
# Removed invalid barossa-valley_2012-08-16_listings.csv.gz and barossa-valley_2012-08-16_listings.csv
# Downloaded barossa-valley_2012-08-16_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-16_reviews.csv.gz and barossa-valley_2012-08-16_reviews.csv
# Downloaded barossa-valley_2012-08-17_listings.csv.gz
# Removed invalid barossa-valley_2012-08-17_listings.csv.gz and barossa-valley_2012-08-17_listings.csv
# Downloaded barossa-valley_2012-08-17_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-17_reviews.csv.gz and barossa-valley_2012-08-17_reviews.csv
# Downloaded barossa-valley_2012-08-18_listings.csv.gz
# Removed invalid barossa-valley_2012-08-18_listings.csv.gz and barossa-valley_2012-08-18_listings.csv
# Downloaded barossa-valley_2012-08-18_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-18_reviews.csv.gz and barossa-valley_2012-08-18_reviews.csv
# Downloaded barossa-valley_2012-08-19_listings.csv.gz
# Removed invalid barossa-valley_2012-08-19_listings.csv.gz and barossa-valley_2012-08-19_listings.csv
# Downloaded barossa-valley_2012-08-19_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-19_reviews.csv.gz and barossa-valley_2012-08-19_reviews.csv
# Downloaded barossa-valley_2012-08-20_listings.csv.gz
# Removed invalid barossa-valley_2012-08-20_listings.csv.gz and barossa-valley_2012-08-20_listings.csv
# Downloaded barossa-valley_2012-08-20_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-20_reviews.csv.gz and barossa-valley_2012-08-20_reviews.csv
# Downloaded barossa-valley_2012-08-21_listings.csv.gz
# Removed invalid barossa-valley_2012-08-21_listings.csv.gz and barossa-valley_2012-08-21_listings.csv
# Downloaded barossa-valley_2012-08-21_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-21_reviews.csv.gz and barossa-valley_2012-08-21_reviews.csv
# Downloaded barossa-valley_2012-08-22_listings.csv.gz
# Removed invalid barossa-valley_2012-08-22_listings.csv.gz and barossa-valley_2012-08-22_listings.csv
# Downloaded barossa-valley_2012-08-22_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-22_reviews.csv.gz and barossa-valley_2012-08-22_reviews.csv
# Downloaded barossa-valley_2012-08-23_listings.csv.gz
# Removed invalid barossa-valley_2012-08-23_listings.csv.gz and barossa-valley_2012-08-23_listings.csv
# Downloaded barossa-valley_2012-08-23_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-23_reviews.csv.gz and barossa-valley_2012-08-23_reviews.csv
# Downloaded barossa-valley_2012-08-24_listings.csv.gz
# Removed invalid barossa-valley_2012-08-24_listings.csv.gz and barossa-valley_2012-08-24_listings.csv
# Downloaded barossa-valley_2012-08-24_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-24_reviews.csv.gz and barossa-valley_2012-08-24_reviews.csv
# Downloaded barossa-valley_2012-08-25_listings.csv.gz
# Removed invalid barossa-valley_2012-08-25_listings.csv.gz and barossa-valley_2012-08-25_listings.csv
# Downloaded barossa-valley_2012-08-25_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-25_reviews.csv.gz and barossa-valley_2012-08-25_reviews.csv
# Downloaded barossa-valley_2012-08-26_listings.csv.gz
# Removed invalid barossa-valley_2012-08-26_listings.csv.gz and barossa-valley_2012-08-26_listings.csv
# Downloaded barossa-valley_2012-08-26_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-26_reviews.csv.gz and barossa-valley_2012-08-26_reviews.csv
# Downloaded barossa-valley_2012-08-27_listings.csv.gz
# Removed invalid barossa-valley_2012-08-27_listings.csv.gz and barossa-valley_2012-08-27_listings.csv
# Downloaded barossa-valley_2012-08-27_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-27_reviews.csv.gz and barossa-valley_2012-08-27_reviews.csv
# Downloaded barossa-valley_2012-08-28_listings.csv.gz
# Removed invalid barossa-valley_2012-08-28_listings.csv.gz and barossa-valley_2012-08-28_listings.csv
# Downloaded barossa-valley_2012-08-28_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-28_reviews.csv.gz and barossa-valley_2012-08-28_reviews.csv
# Downloaded barossa-valley_2012-08-29_listings.csv.gz
# Removed invalid barossa-valley_2012-08-29_listings.csv.gz and barossa-valley_2012-08-29_listings.csv
# Downloaded barossa-valley_2012-08-29_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-29_reviews.csv.gz and barossa-valley_2012-08-29_reviews.csv
# Downloaded barossa-valley_2012-08-30_listings.csv.gz
# Removed invalid barossa-valley_2012-08-30_listings.csv.gz and barossa-valley_2012-08-30_listings.csv
# Downloaded barossa-valley_2012-08-30_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-30_reviews.csv.gz and barossa-valley_2012-08-30_reviews.csv
# Downloaded barossa-valley_2012-08-31_listings.csv.gz
# Removed invalid barossa-valley_2012-08-31_listings.csv.gz and barossa-valley_2012-08-31_listings.csv
# Downloaded barossa-valley_2012-08-31_reviews.csv.gz
# Removed invalid barossa-valley_2012-08-31_reviews.csv.gz and barossa-valley_2012-08-31_reviews.csv
# Downloaded barossa-valley_2012-09-01_listings.csv.gz
# Removed invalid barossa-valley_2012-09-01_listings.csv.gz and barossa-valley_2012-09-01_listings.csv
# Downloaded barossa-valley_2012-09-01_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-01_reviews.csv.gz and barossa-valley_2012-09-01_reviews.csv
# Downloaded barossa-valley_2012-09-02_listings.csv.gz
# Removed invalid barossa-valley_2012-09-02_listings.csv.gz and barossa-valley_2012-09-02_listings.csv
# Downloaded barossa-valley_2012-09-02_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-02_reviews.csv.gz and barossa-valley_2012-09-02_reviews.csv
# Downloaded barossa-valley_2012-09-03_listings.csv.gz
# Removed invalid barossa-valley_2012-09-03_listings.csv.gz and barossa-valley_2012-09-03_listings.csv
# Downloaded barossa-valley_2012-09-03_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-03_reviews.csv.gz and barossa-valley_2012-09-03_reviews.csv
# Downloaded barossa-valley_2012-09-04_listings.csv.gz
# Removed invalid barossa-valley_2012-09-04_listings.csv.gz and barossa-valley_2012-09-04_listings.csv
# Downloaded barossa-valley_2012-09-04_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-04_reviews.csv.gz and barossa-valley_2012-09-04_reviews.csv
# Downloaded barossa-valley_2012-09-05_listings.csv.gz
# Removed invalid barossa-valley_2012-09-05_listings.csv.gz and barossa-valley_2012-09-05_listings.csv
# Downloaded barossa-valley_2012-09-05_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-05_reviews.csv.gz and barossa-valley_2012-09-05_reviews.csv
# Downloaded barossa-valley_2012-09-06_listings.csv.gz
# Removed invalid barossa-valley_2012-09-06_listings.csv.gz and barossa-valley_2012-09-06_listings.csv
# Downloaded barossa-valley_2012-09-06_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-06_reviews.csv.gz and barossa-valley_2012-09-06_reviews.csv
# Downloaded barossa-valley_2012-09-07_listings.csv.gz
# Removed invalid barossa-valley_2012-09-07_listings.csv.gz and barossa-valley_2012-09-07_listings.csv
# Downloaded barossa-valley_2012-09-07_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-07_reviews.csv.gz and barossa-valley_2012-09-07_reviews.csv
# Downloaded barossa-valley_2012-09-08_listings.csv.gz
# Removed invalid barossa-valley_2012-09-08_listings.csv.gz and barossa-valley_2012-09-08_listings.csv
# Downloaded barossa-valley_2012-09-08_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-08_reviews.csv.gz and barossa-valley_2012-09-08_reviews.csv
# Downloaded barossa-valley_2012-09-09_listings.csv.gz
# Removed invalid barossa-valley_2012-09-09_listings.csv.gz and barossa-valley_2012-09-09_listings.csv
# Downloaded barossa-valley_2012-09-09_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-09_reviews.csv.gz and barossa-valley_2012-09-09_reviews.csv
# Downloaded barossa-valley_2012-09-10_listings.csv.gz
# Removed invalid barossa-valley_2012-09-10_listings.csv.gz and barossa-valley_2012-09-10_listings.csv
# Downloaded barossa-valley_2012-09-10_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-10_reviews.csv.gz and barossa-valley_2012-09-10_reviews.csv
# Downloaded barossa-valley_2012-09-11_listings.csv.gz
# Removed invalid barossa-valley_2012-09-11_listings.csv.gz and barossa-valley_2012-09-11_listings.csv
# Downloaded barossa-valley_2012-09-11_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-11_reviews.csv.gz and barossa-valley_2012-09-11_reviews.csv
# Downloaded barossa-valley_2012-09-12_listings.csv.gz
# Removed invalid barossa-valley_2012-09-12_listings.csv.gz and barossa-valley_2012-09-12_listings.csv
# Downloaded barossa-valley_2012-09-12_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-12_reviews.csv.gz and barossa-valley_2012-09-12_reviews.csv
# Downloaded barossa-valley_2012-09-13_listings.csv.gz
# Removed invalid barossa-valley_2012-09-13_listings.csv.gz and barossa-valley_2012-09-13_listings.csv
# Downloaded barossa-valley_2012-09-13_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-13_reviews.csv.gz and barossa-valley_2012-09-13_reviews.csv
# Downloaded barossa-valley_2012-09-14_listings.csv.gz
# Removed invalid barossa-valley_2012-09-14_listings.csv.gz and barossa-valley_2012-09-14_listings.csv
# Downloaded barossa-valley_2012-09-14_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-14_reviews.csv.gz and barossa-valley_2012-09-14_reviews.csv
# Downloaded barossa-valley_2012-09-15_listings.csv.gz
# Removed invalid barossa-valley_2012-09-15_listings.csv.gz and barossa-valley_2012-09-15_listings.csv
# Downloaded barossa-valley_2012-09-15_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-15_reviews.csv.gz and barossa-valley_2012-09-15_reviews.csv
# Downloaded barossa-valley_2012-09-16_listings.csv.gz
# Removed invalid barossa-valley_2012-09-16_listings.csv.gz and barossa-valley_2012-09-16_listings.csv
# Downloaded barossa-valley_2012-09-16_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-16_reviews.csv.gz and barossa-valley_2012-09-16_reviews.csv
# Downloaded barossa-valley_2012-09-17_listings.csv.gz
# Removed invalid barossa-valley_2012-09-17_listings.csv.gz and barossa-valley_2012-09-17_listings.csv
# Downloaded barossa-valley_2012-09-17_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-17_reviews.csv.gz and barossa-valley_2012-09-17_reviews.csv
# Downloaded barossa-valley_2012-09-18_listings.csv.gz
# Removed invalid barossa-valley_2012-09-18_listings.csv.gz and barossa-valley_2012-09-18_listings.csv
# Downloaded barossa-valley_2012-09-18_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-18_reviews.csv.gz and barossa-valley_2012-09-18_reviews.csv
# Downloaded barossa-valley_2012-09-19_listings.csv.gz
# Removed invalid barossa-valley_2012-09-19_listings.csv.gz and barossa-valley_2012-09-19_listings.csv
# Downloaded barossa-valley_2012-09-19_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-19_reviews.csv.gz and barossa-valley_2012-09-19_reviews.csv
# Downloaded barossa-valley_2012-09-20_listings.csv.gz
# Removed invalid barossa-valley_2012-09-20_listings.csv.gz and barossa-valley_2012-09-20_listings.csv
# Downloaded barossa-valley_2012-09-20_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-20_reviews.csv.gz and barossa-valley_2012-09-20_reviews.csv
# Downloaded barossa-valley_2012-09-21_listings.csv.gz
# Removed invalid barossa-valley_2012-09-21_listings.csv.gz and barossa-valley_2012-09-21_listings.csv
# Downloaded barossa-valley_2012-09-21_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-21_reviews.csv.gz and barossa-valley_2012-09-21_reviews.csv
# Downloaded barossa-valley_2012-09-22_listings.csv.gz
# Removed invalid barossa-valley_2012-09-22_listings.csv.gz and barossa-valley_2012-09-22_listings.csv
# Downloaded barossa-valley_2012-09-22_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-22_reviews.csv.gz and barossa-valley_2012-09-22_reviews.csv
# Downloaded barossa-valley_2012-09-23_listings.csv.gz
# Removed invalid barossa-valley_2012-09-23_listings.csv.gz and barossa-valley_2012-09-23_listings.csv
# Downloaded barossa-valley_2012-09-23_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-23_reviews.csv.gz and barossa-valley_2012-09-23_reviews.csv
# Downloaded barossa-valley_2012-09-24_listings.csv.gz
# Removed invalid barossa-valley_2012-09-24_listings.csv.gz and barossa-valley_2012-09-24_listings.csv
# Downloaded barossa-valley_2012-09-24_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-24_reviews.csv.gz and barossa-valley_2012-09-24_reviews.csv
# Downloaded barossa-valley_2012-09-25_listings.csv.gz
# Removed invalid barossa-valley_2012-09-25_listings.csv.gz and barossa-valley_2012-09-25_listings.csv
# Downloaded barossa-valley_2012-09-25_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-25_reviews.csv.gz and barossa-valley_2012-09-25_reviews.csv
# Downloaded barossa-valley_2012-09-26_listings.csv.gz
# Removed invalid barossa-valley_2012-09-26_listings.csv.gz and barossa-valley_2012-09-26_listings.csv
# Downloaded barossa-valley_2012-09-26_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-26_reviews.csv.gz and barossa-valley_2012-09-26_reviews.csv
# Downloaded barossa-valley_2012-09-27_listings.csv.gz
# Removed invalid barossa-valley_2012-09-27_listings.csv.gz and barossa-valley_2012-09-27_listings.csv
# Downloaded barossa-valley_2012-09-27_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-27_reviews.csv.gz and barossa-valley_2012-09-27_reviews.csv
# Downloaded barossa-valley_2012-09-28_listings.csv.gz
# Removed invalid barossa-valley_2012-09-28_listings.csv.gz and barossa-valley_2012-09-28_listings.csv
# Downloaded barossa-valley_2012-09-28_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-28_reviews.csv.gz and barossa-valley_2012-09-28_reviews.csv
# Downloaded barossa-valley_2012-09-29_listings.csv.gz
# Removed invalid barossa-valley_2012-09-29_listings.csv.gz and barossa-valley_2012-09-29_listings.csv
# Downloaded barossa-valley_2012-09-29_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-29_reviews.csv.gz and barossa-valley_2012-09-29_reviews.csv
# Downloaded barossa-valley_2012-09-30_listings.csv.gz
# Removed invalid barossa-valley_2012-09-30_listings.csv.gz and barossa-valley_2012-09-30_listings.csv
# Downloaded barossa-valley_2012-09-30_reviews.csv.gz
# Removed invalid barossa-valley_2012-09-30_reviews.csv.gz and barossa-valley_2012-09-30_reviews.csv
# Downloaded barossa-valley_2012-10-01_listings.csv.gz
# Removed invalid barossa-valley_2012-10-01_listings.csv.gz and barossa-valley_2012-10-01_listings.csv
# Downloaded barossa-valley_2012-10-01_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-01_reviews.csv.gz and barossa-valley_2012-10-01_reviews.csv
# Downloaded barossa-valley_2012-10-02_listings.csv.gz
# Removed invalid barossa-valley_2012-10-02_listings.csv.gz and barossa-valley_2012-10-02_listings.csv
# Downloaded barossa-valley_2012-10-02_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-02_reviews.csv.gz and barossa-valley_2012-10-02_reviews.csv
# Downloaded barossa-valley_2012-10-03_listings.csv.gz
# Removed invalid barossa-valley_2012-10-03_listings.csv.gz and barossa-valley_2012-10-03_listings.csv
# Downloaded barossa-valley_2012-10-03_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-03_reviews.csv.gz and barossa-valley_2012-10-03_reviews.csv
# Downloaded barossa-valley_2012-10-04_listings.csv.gz
# Removed invalid barossa-valley_2012-10-04_listings.csv.gz and barossa-valley_2012-10-04_listings.csv
# Downloaded barossa-valley_2012-10-04_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-04_reviews.csv.gz and barossa-valley_2012-10-04_reviews.csv
# Downloaded barossa-valley_2012-10-05_listings.csv.gz
# Removed invalid barossa-valley_2012-10-05_listings.csv.gz and barossa-valley_2012-10-05_listings.csv
# Downloaded barossa-valley_2012-10-05_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-05_reviews.csv.gz and barossa-valley_2012-10-05_reviews.csv
# Downloaded barossa-valley_2012-10-06_listings.csv.gz
# Removed invalid barossa-valley_2012-10-06_listings.csv.gz and barossa-valley_2012-10-06_listings.csv
# Downloaded barossa-valley_2012-10-06_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-06_reviews.csv.gz and barossa-valley_2012-10-06_reviews.csv
# Downloaded barossa-valley_2012-10-07_listings.csv.gz
# Removed invalid barossa-valley_2012-10-07_listings.csv.gz and barossa-valley_2012-10-07_listings.csv
# Downloaded barossa-valley_2012-10-07_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-07_reviews.csv.gz and barossa-valley_2012-10-07_reviews.csv
# Downloaded barossa-valley_2012-10-08_listings.csv.gz
# Removed invalid barossa-valley_2012-10-08_listings.csv.gz and barossa-valley_2012-10-08_listings.csv
# Downloaded barossa-valley_2012-10-08_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-08_reviews.csv.gz and barossa-valley_2012-10-08_reviews.csv
# Downloaded barossa-valley_2012-10-09_listings.csv.gz
# Removed invalid barossa-valley_2012-10-09_listings.csv.gz and barossa-valley_2012-10-09_listings.csv
# Downloaded barossa-valley_2012-10-09_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-09_reviews.csv.gz and barossa-valley_2012-10-09_reviews.csv
# Downloaded barossa-valley_2012-10-10_listings.csv.gz
# Removed invalid barossa-valley_2012-10-10_listings.csv.gz and barossa-valley_2012-10-10_listings.csv
# Downloaded barossa-valley_2012-10-10_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-10_reviews.csv.gz and barossa-valley_2012-10-10_reviews.csv
# Downloaded barossa-valley_2012-10-11_listings.csv.gz
# Removed invalid barossa-valley_2012-10-11_listings.csv.gz and barossa-valley_2012-10-11_listings.csv
# Downloaded barossa-valley_2012-10-11_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-11_reviews.csv.gz and barossa-valley_2012-10-11_reviews.csv
# Downloaded barossa-valley_2012-10-12_listings.csv.gz
# Removed invalid barossa-valley_2012-10-12_listings.csv.gz and barossa-valley_2012-10-12_listings.csv
# Downloaded barossa-valley_2012-10-12_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-12_reviews.csv.gz and barossa-valley_2012-10-12_reviews.csv
# Downloaded barossa-valley_2012-10-13_listings.csv.gz
# Removed invalid barossa-valley_2012-10-13_listings.csv.gz and barossa-valley_2012-10-13_listings.csv
# Downloaded barossa-valley_2012-10-13_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-13_reviews.csv.gz and barossa-valley_2012-10-13_reviews.csv
# Downloaded barossa-valley_2012-10-14_listings.csv.gz
# Removed invalid barossa-valley_2012-10-14_listings.csv.gz and barossa-valley_2012-10-14_listings.csv
# Downloaded barossa-valley_2012-10-14_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-14_reviews.csv.gz and barossa-valley_2012-10-14_reviews.csv
# Downloaded barossa-valley_2012-10-15_listings.csv.gz
# Removed invalid barossa-valley_2012-10-15_listings.csv.gz and barossa-valley_2012-10-15_listings.csv
# Downloaded barossa-valley_2012-10-15_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-15_reviews.csv.gz and barossa-valley_2012-10-15_reviews.csv
# Downloaded barossa-valley_2012-10-16_listings.csv.gz
# Removed invalid barossa-valley_2012-10-16_listings.csv.gz and barossa-valley_2012-10-16_listings.csv
# Downloaded barossa-valley_2012-10-16_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-16_reviews.csv.gz and barossa-valley_2012-10-16_reviews.csv
# Downloaded barossa-valley_2012-10-17_listings.csv.gz
# Removed invalid barossa-valley_2012-10-17_listings.csv.gz and barossa-valley_2012-10-17_listings.csv
# Downloaded barossa-valley_2012-10-17_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-17_reviews.csv.gz and barossa-valley_2012-10-17_reviews.csv
# Downloaded barossa-valley_2012-10-18_listings.csv.gz
# Removed invalid barossa-valley_2012-10-18_listings.csv.gz and barossa-valley_2012-10-18_listings.csv
# Downloaded barossa-valley_2012-10-18_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-18_reviews.csv.gz and barossa-valley_2012-10-18_reviews.csv
# Downloaded barossa-valley_2012-10-19_listings.csv.gz
# Removed invalid barossa-valley_2012-10-19_listings.csv.gz and barossa-valley_2012-10-19_listings.csv
# Downloaded barossa-valley_2012-10-19_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-19_reviews.csv.gz and barossa-valley_2012-10-19_reviews.csv
# Downloaded barossa-valley_2012-10-20_listings.csv.gz
# Removed invalid barossa-valley_2012-10-20_listings.csv.gz and barossa-valley_2012-10-20_listings.csv
# Downloaded barossa-valley_2012-10-20_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-20_reviews.csv.gz and barossa-valley_2012-10-20_reviews.csv
# Downloaded barossa-valley_2012-10-21_listings.csv.gz
# Removed invalid barossa-valley_2012-10-21_listings.csv.gz and barossa-valley_2012-10-21_listings.csv
# Downloaded barossa-valley_2012-10-21_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-21_reviews.csv.gz and barossa-valley_2012-10-21_reviews.csv
# Downloaded barossa-valley_2012-10-22_listings.csv.gz
# Removed invalid barossa-valley_2012-10-22_listings.csv.gz and barossa-valley_2012-10-22_listings.csv
# Downloaded barossa-valley_2012-10-22_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-22_reviews.csv.gz and barossa-valley_2012-10-22_reviews.csv
# Downloaded barossa-valley_2012-10-23_listings.csv.gz
# Removed invalid barossa-valley_2012-10-23_listings.csv.gz and barossa-valley_2012-10-23_listings.csv
# Downloaded barossa-valley_2012-10-23_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-23_reviews.csv.gz and barossa-valley_2012-10-23_reviews.csv
# Downloaded barossa-valley_2012-10-24_listings.csv.gz
# Removed invalid barossa-valley_2012-10-24_listings.csv.gz and barossa-valley_2012-10-24_listings.csv
# Downloaded barossa-valley_2012-10-24_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-24_reviews.csv.gz and barossa-valley_2012-10-24_reviews.csv
# Downloaded barossa-valley_2012-10-25_listings.csv.gz
# Removed invalid barossa-valley_2012-10-25_listings.csv.gz and barossa-valley_2012-10-25_listings.csv
# Downloaded barossa-valley_2012-10-25_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-25_reviews.csv.gz and barossa-valley_2012-10-25_reviews.csv
# Downloaded barossa-valley_2012-10-26_listings.csv.gz
# Removed invalid barossa-valley_2012-10-26_listings.csv.gz and barossa-valley_2012-10-26_listings.csv
# Downloaded barossa-valley_2012-10-26_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-26_reviews.csv.gz and barossa-valley_2012-10-26_reviews.csv
# Downloaded barossa-valley_2012-10-27_listings.csv.gz
# Removed invalid barossa-valley_2012-10-27_listings.csv.gz and barossa-valley_2012-10-27_listings.csv
# Downloaded barossa-valley_2012-10-27_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-27_reviews.csv.gz and barossa-valley_2012-10-27_reviews.csv
# Downloaded barossa-valley_2012-10-28_listings.csv.gz
# Removed invalid barossa-valley_2012-10-28_listings.csv.gz and barossa-valley_2012-10-28_listings.csv
# Downloaded barossa-valley_2012-10-28_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-28_reviews.csv.gz and barossa-valley_2012-10-28_reviews.csv
# Downloaded barossa-valley_2012-10-29_listings.csv.gz
# Removed invalid barossa-valley_2012-10-29_listings.csv.gz and barossa-valley_2012-10-29_listings.csv
# Downloaded barossa-valley_2012-10-29_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-29_reviews.csv.gz and barossa-valley_2012-10-29_reviews.csv
# Downloaded barossa-valley_2012-10-30_listings.csv.gz
# Removed invalid barossa-valley_2012-10-30_listings.csv.gz and barossa-valley_2012-10-30_listings.csv
# Downloaded barossa-valley_2012-10-30_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-30_reviews.csv.gz and barossa-valley_2012-10-30_reviews.csv
# Downloaded barossa-valley_2012-10-31_listings.csv.gz
# Removed invalid barossa-valley_2012-10-31_listings.csv.gz and barossa-valley_2012-10-31_listings.csv
# Downloaded barossa-valley_2012-10-31_reviews.csv.gz
# Removed invalid barossa-valley_2012-10-31_reviews.csv.gz and barossa-valley_2012-10-31_reviews.csv
# Downloaded barossa-valley_2012-11-01_listings.csv.gz
# Removed invalid barossa-valley_2012-11-01_listings.csv.gz and barossa-valley_2012-11-01_listings.csv
# Downloaded barossa-valley_2012-11-01_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-01_reviews.csv.gz and barossa-valley_2012-11-01_reviews.csv
# Downloaded barossa-valley_2012-11-02_listings.csv.gz
# Removed invalid barossa-valley_2012-11-02_listings.csv.gz and barossa-valley_2012-11-02_listings.csv
# Downloaded barossa-valley_2012-11-02_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-02_reviews.csv.gz and barossa-valley_2012-11-02_reviews.csv
# Downloaded barossa-valley_2012-11-03_listings.csv.gz
# Removed invalid barossa-valley_2012-11-03_listings.csv.gz and barossa-valley_2012-11-03_listings.csv
# Downloaded barossa-valley_2012-11-03_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-03_reviews.csv.gz and barossa-valley_2012-11-03_reviews.csv
# Downloaded barossa-valley_2012-11-04_listings.csv.gz
# Removed invalid barossa-valley_2012-11-04_listings.csv.gz and barossa-valley_2012-11-04_listings.csv
# Downloaded barossa-valley_2012-11-04_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-04_reviews.csv.gz and barossa-valley_2012-11-04_reviews.csv
# Downloaded barossa-valley_2012-11-05_listings.csv.gz
# Removed invalid barossa-valley_2012-11-05_listings.csv.gz and barossa-valley_2012-11-05_listings.csv
# Downloaded barossa-valley_2012-11-05_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-05_reviews.csv.gz and barossa-valley_2012-11-05_reviews.csv
# Downloaded barossa-valley_2012-11-06_listings.csv.gz
# Removed invalid barossa-valley_2012-11-06_listings.csv.gz and barossa-valley_2012-11-06_listings.csv
# Downloaded barossa-valley_2012-11-06_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-06_reviews.csv.gz and barossa-valley_2012-11-06_reviews.csv
# Downloaded barossa-valley_2012-11-07_listings.csv.gz
# Removed invalid barossa-valley_2012-11-07_listings.csv.gz and barossa-valley_2012-11-07_listings.csv
# Downloaded barossa-valley_2012-11-07_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-07_reviews.csv.gz and barossa-valley_2012-11-07_reviews.csv
# Downloaded barossa-valley_2012-11-08_listings.csv.gz
# Removed invalid barossa-valley_2012-11-08_listings.csv.gz and barossa-valley_2012-11-08_listings.csv
# Downloaded barossa-valley_2012-11-08_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-08_reviews.csv.gz and barossa-valley_2012-11-08_reviews.csv
# Downloaded barossa-valley_2012-11-09_listings.csv.gz
# Removed invalid barossa-valley_2012-11-09_listings.csv.gz and barossa-valley_2012-11-09_listings.csv
# Downloaded barossa-valley_2012-11-09_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-09_reviews.csv.gz and barossa-valley_2012-11-09_reviews.csv
# Downloaded barossa-valley_2012-11-10_listings.csv.gz
# Removed invalid barossa-valley_2012-11-10_listings.csv.gz and barossa-valley_2012-11-10_listings.csv
# Downloaded barossa-valley_2012-11-10_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-10_reviews.csv.gz and barossa-valley_2012-11-10_reviews.csv
# Downloaded barossa-valley_2012-11-11_listings.csv.gz
# Removed invalid barossa-valley_2012-11-11_listings.csv.gz and barossa-valley_2012-11-11_listings.csv
# Downloaded barossa-valley_2012-11-11_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-11_reviews.csv.gz and barossa-valley_2012-11-11_reviews.csv
# Downloaded barossa-valley_2012-11-12_listings.csv.gz
# Removed invalid barossa-valley_2012-11-12_listings.csv.gz and barossa-valley_2012-11-12_listings.csv
# Downloaded barossa-valley_2012-11-12_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-12_reviews.csv.gz and barossa-valley_2012-11-12_reviews.csv
# Downloaded barossa-valley_2012-11-13_listings.csv.gz
# Removed invalid barossa-valley_2012-11-13_listings.csv.gz and barossa-valley_2012-11-13_listings.csv
# Downloaded barossa-valley_2012-11-13_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-13_reviews.csv.gz and barossa-valley_2012-11-13_reviews.csv
# Downloaded barossa-valley_2012-11-14_listings.csv.gz
# Removed invalid barossa-valley_2012-11-14_listings.csv.gz and barossa-valley_2012-11-14_listings.csv
# Downloaded barossa-valley_2012-11-14_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-14_reviews.csv.gz and barossa-valley_2012-11-14_reviews.csv
# Downloaded barossa-valley_2012-11-15_listings.csv.gz
# Removed invalid barossa-valley_2012-11-15_listings.csv.gz and barossa-valley_2012-11-15_listings.csv
# Downloaded barossa-valley_2012-11-15_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-15_reviews.csv.gz and barossa-valley_2012-11-15_reviews.csv
# Downloaded barossa-valley_2012-11-16_listings.csv.gz
# Removed invalid barossa-valley_2012-11-16_listings.csv.gz and barossa-valley_2012-11-16_listings.csv
# Downloaded barossa-valley_2012-11-16_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-16_reviews.csv.gz and barossa-valley_2012-11-16_reviews.csv
# Downloaded barossa-valley_2012-11-17_listings.csv.gz
# Removed invalid barossa-valley_2012-11-17_listings.csv.gz and barossa-valley_2012-11-17_listings.csv
# Downloaded barossa-valley_2012-11-17_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-17_reviews.csv.gz and barossa-valley_2012-11-17_reviews.csv
# Downloaded barossa-valley_2012-11-18_listings.csv.gz
# Removed invalid barossa-valley_2012-11-18_listings.csv.gz and barossa-valley_2012-11-18_listings.csv
# Downloaded barossa-valley_2012-11-18_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-18_reviews.csv.gz and barossa-valley_2012-11-18_reviews.csv
# Downloaded barossa-valley_2012-11-19_listings.csv.gz
# Removed invalid barossa-valley_2012-11-19_listings.csv.gz and barossa-valley_2012-11-19_listings.csv
# Downloaded barossa-valley_2012-11-19_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-19_reviews.csv.gz and barossa-valley_2012-11-19_reviews.csv
# Downloaded barossa-valley_2012-11-20_listings.csv.gz
# Removed invalid barossa-valley_2012-11-20_listings.csv.gz and barossa-valley_2012-11-20_listings.csv
# Downloaded barossa-valley_2012-11-20_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-20_reviews.csv.gz and barossa-valley_2012-11-20_reviews.csv
# Downloaded barossa-valley_2012-11-21_listings.csv.gz
# Removed invalid barossa-valley_2012-11-21_listings.csv.gz and barossa-valley_2012-11-21_listings.csv
# Downloaded barossa-valley_2012-11-21_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-21_reviews.csv.gz and barossa-valley_2012-11-21_reviews.csv
# Downloaded barossa-valley_2012-11-22_listings.csv.gz
# Removed invalid barossa-valley_2012-11-22_listings.csv.gz and barossa-valley_2012-11-22_listings.csv
# Downloaded barossa-valley_2012-11-22_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-22_reviews.csv.gz and barossa-valley_2012-11-22_reviews.csv
# Downloaded barossa-valley_2012-11-23_listings.csv.gz
# Removed invalid barossa-valley_2012-11-23_listings.csv.gz and barossa-valley_2012-11-23_listings.csv
# Downloaded barossa-valley_2012-11-23_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-23_reviews.csv.gz and barossa-valley_2012-11-23_reviews.csv
# Downloaded barossa-valley_2012-11-24_listings.csv.gz
# Removed invalid barossa-valley_2012-11-24_listings.csv.gz and barossa-valley_2012-11-24_listings.csv
# Downloaded barossa-valley_2012-11-24_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-24_reviews.csv.gz and barossa-valley_2012-11-24_reviews.csv
# Downloaded barossa-valley_2012-11-25_listings.csv.gz
# Removed invalid barossa-valley_2012-11-25_listings.csv.gz and barossa-valley_2012-11-25_listings.csv
# Downloaded barossa-valley_2012-11-25_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-25_reviews.csv.gz and barossa-valley_2012-11-25_reviews.csv
# Downloaded barossa-valley_2012-11-26_listings.csv.gz
# Removed invalid barossa-valley_2012-11-26_listings.csv.gz and barossa-valley_2012-11-26_listings.csv
# Downloaded barossa-valley_2012-11-26_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-26_reviews.csv.gz and barossa-valley_2012-11-26_reviews.csv
# Downloaded barossa-valley_2012-11-27_listings.csv.gz
# Removed invalid barossa-valley_2012-11-27_listings.csv.gz and barossa-valley_2012-11-27_listings.csv
# Downloaded barossa-valley_2012-11-27_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-27_reviews.csv.gz and barossa-valley_2012-11-27_reviews.csv
# Downloaded barossa-valley_2012-11-28_listings.csv.gz
# Removed invalid barossa-valley_2012-11-28_listings.csv.gz and barossa-valley_2012-11-28_listings.csv
# Downloaded barossa-valley_2012-11-28_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-28_reviews.csv.gz and barossa-valley_2012-11-28_reviews.csv
# Downloaded barossa-valley_2012-11-29_listings.csv.gz
# Removed invalid barossa-valley_2012-11-29_listings.csv.gz and barossa-valley_2012-11-29_listings.csv
# Downloaded barossa-valley_2012-11-29_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-29_reviews.csv.gz and barossa-valley_2012-11-29_reviews.csv
# Downloaded barossa-valley_2012-11-30_listings.csv.gz
# Removed invalid barossa-valley_2012-11-30_listings.csv.gz and barossa-valley_2012-11-30_listings.csv
# Downloaded barossa-valley_2012-11-30_reviews.csv.gz
# Removed invalid barossa-valley_2012-11-30_reviews.csv.gz and barossa-valley_2012-11-30_reviews.csv
# Downloaded barossa-valley_2012-12-01_listings.csv.gz
# Removed invalid barossa-valley_2012-12-01_listings.csv.gz and barossa-valley_2012-12-01_listings.csv
# Downloaded barossa-valley_2012-12-01_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-01_reviews.csv.gz and barossa-valley_2012-12-01_reviews.csv
# Downloaded barossa-valley_2012-12-02_listings.csv.gz
# Removed invalid barossa-valley_2012-12-02_listings.csv.gz and barossa-valley_2012-12-02_listings.csv
# Downloaded barossa-valley_2012-12-02_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-02_reviews.csv.gz and barossa-valley_2012-12-02_reviews.csv
# Downloaded barossa-valley_2012-12-03_listings.csv.gz
# Removed invalid barossa-valley_2012-12-03_listings.csv.gz and barossa-valley_2012-12-03_listings.csv
# Downloaded barossa-valley_2012-12-03_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-03_reviews.csv.gz and barossa-valley_2012-12-03_reviews.csv
# Downloaded barossa-valley_2012-12-04_listings.csv.gz
# Removed invalid barossa-valley_2012-12-04_listings.csv.gz and barossa-valley_2012-12-04_listings.csv
# Downloaded barossa-valley_2012-12-04_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-04_reviews.csv.gz and barossa-valley_2012-12-04_reviews.csv
# Downloaded barossa-valley_2012-12-05_listings.csv.gz
# Removed invalid barossa-valley_2012-12-05_listings.csv.gz and barossa-valley_2012-12-05_listings.csv
# Downloaded barossa-valley_2012-12-05_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-05_reviews.csv.gz and barossa-valley_2012-12-05_reviews.csv
# Downloaded barossa-valley_2012-12-06_listings.csv.gz
# Removed invalid barossa-valley_2012-12-06_listings.csv.gz and barossa-valley_2012-12-06_listings.csv
# Downloaded barossa-valley_2012-12-06_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-06_reviews.csv.gz and barossa-valley_2012-12-06_reviews.csv
# Downloaded barossa-valley_2012-12-07_listings.csv.gz
# Removed invalid barossa-valley_2012-12-07_listings.csv.gz and barossa-valley_2012-12-07_listings.csv
# Downloaded barossa-valley_2012-12-07_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-07_reviews.csv.gz and barossa-valley_2012-12-07_reviews.csv
# Downloaded barossa-valley_2012-12-08_listings.csv.gz
# Removed invalid barossa-valley_2012-12-08_listings.csv.gz and barossa-valley_2012-12-08_listings.csv
# Downloaded barossa-valley_2012-12-08_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-08_reviews.csv.gz and barossa-valley_2012-12-08_reviews.csv
# Downloaded barossa-valley_2012-12-09_listings.csv.gz
# Removed invalid barossa-valley_2012-12-09_listings.csv.gz and barossa-valley_2012-12-09_listings.csv
# Downloaded barossa-valley_2012-12-09_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-09_reviews.csv.gz and barossa-valley_2012-12-09_reviews.csv
# Downloaded barossa-valley_2012-12-10_listings.csv.gz
# Removed invalid barossa-valley_2012-12-10_listings.csv.gz and barossa-valley_2012-12-10_listings.csv
# Downloaded barossa-valley_2012-12-10_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-10_reviews.csv.gz and barossa-valley_2012-12-10_reviews.csv
# Downloaded barossa-valley_2012-12-11_listings.csv.gz
# Removed invalid barossa-valley_2012-12-11_listings.csv.gz and barossa-valley_2012-12-11_listings.csv
# Downloaded barossa-valley_2012-12-11_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-11_reviews.csv.gz and barossa-valley_2012-12-11_reviews.csv
# Downloaded barossa-valley_2012-12-12_listings.csv.gz
# Removed invalid barossa-valley_2012-12-12_listings.csv.gz and barossa-valley_2012-12-12_listings.csv
# Downloaded barossa-valley_2012-12-12_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-12_reviews.csv.gz and barossa-valley_2012-12-12_reviews.csv
# Downloaded barossa-valley_2012-12-13_listings.csv.gz
# Removed invalid barossa-valley_2012-12-13_listings.csv.gz and barossa-valley_2012-12-13_listings.csv
# Downloaded barossa-valley_2012-12-13_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-13_reviews.csv.gz and barossa-valley_2012-12-13_reviews.csv
# Downloaded barossa-valley_2012-12-14_listings.csv.gz
# Removed invalid barossa-valley_2012-12-14_listings.csv.gz and barossa-valley_2012-12-14_listings.csv
# Downloaded barossa-valley_2012-12-14_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-14_reviews.csv.gz and barossa-valley_2012-12-14_reviews.csv
# Downloaded barossa-valley_2012-12-15_listings.csv.gz
# Removed invalid barossa-valley_2012-12-15_listings.csv.gz and barossa-valley_2012-12-15_listings.csv
# Downloaded barossa-valley_2012-12-15_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-15_reviews.csv.gz and barossa-valley_2012-12-15_reviews.csv
# Downloaded barossa-valley_2012-12-16_listings.csv.gz
# Removed invalid barossa-valley_2012-12-16_listings.csv.gz and barossa-valley_2012-12-16_listings.csv
# Downloaded barossa-valley_2012-12-16_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-16_reviews.csv.gz and barossa-valley_2012-12-16_reviews.csv
# Downloaded barossa-valley_2012-12-17_listings.csv.gz
# Removed invalid barossa-valley_2012-12-17_listings.csv.gz and barossa-valley_2012-12-17_listings.csv
# Downloaded barossa-valley_2012-12-17_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-17_reviews.csv.gz and barossa-valley_2012-12-17_reviews.csv
# Downloaded barossa-valley_2012-12-18_listings.csv.gz
# Removed invalid barossa-valley_2012-12-18_listings.csv.gz and barossa-valley_2012-12-18_listings.csv
# Downloaded barossa-valley_2012-12-18_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-18_reviews.csv.gz and barossa-valley_2012-12-18_reviews.csv
# Downloaded barossa-valley_2012-12-19_listings.csv.gz
# Removed invalid barossa-valley_2012-12-19_listings.csv.gz and barossa-valley_2012-12-19_listings.csv
# Downloaded barossa-valley_2012-12-19_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-19_reviews.csv.gz and barossa-valley_2012-12-19_reviews.csv
# Downloaded barossa-valley_2012-12-20_listings.csv.gz
# Removed invalid barossa-valley_2012-12-20_listings.csv.gz and barossa-valley_2012-12-20_listings.csv
# Downloaded barossa-valley_2012-12-20_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-20_reviews.csv.gz and barossa-valley_2012-12-20_reviews.csv
# Downloaded barossa-valley_2012-12-21_listings.csv.gz
# Removed invalid barossa-valley_2012-12-21_listings.csv.gz and barossa-valley_2012-12-21_listings.csv
# Downloaded barossa-valley_2012-12-21_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-21_reviews.csv.gz and barossa-valley_2012-12-21_reviews.csv
# Downloaded barossa-valley_2012-12-22_listings.csv.gz
# Removed invalid barossa-valley_2012-12-22_listings.csv.gz and barossa-valley_2012-12-22_listings.csv
# Downloaded barossa-valley_2012-12-22_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-22_reviews.csv.gz and barossa-valley_2012-12-22_reviews.csv
# Downloaded barossa-valley_2012-12-23_listings.csv.gz
# Removed invalid barossa-valley_2012-12-23_listings.csv.gz and barossa-valley_2012-12-23_listings.csv
# Downloaded barossa-valley_2012-12-23_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-23_reviews.csv.gz and barossa-valley_2012-12-23_reviews.csv
# Downloaded barossa-valley_2012-12-24_listings.csv.gz
# Removed invalid barossa-valley_2012-12-24_listings.csv.gz and barossa-valley_2012-12-24_listings.csv
# Downloaded barossa-valley_2012-12-24_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-24_reviews.csv.gz and barossa-valley_2012-12-24_reviews.csv
# Downloaded barossa-valley_2012-12-25_listings.csv.gz
# Removed invalid barossa-valley_2012-12-25_listings.csv.gz and barossa-valley_2012-12-25_listings.csv
# Downloaded barossa-valley_2012-12-25_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-25_reviews.csv.gz and barossa-valley_2012-12-25_reviews.csv
# Downloaded barossa-valley_2012-12-26_listings.csv.gz
# Removed invalid barossa-valley_2012-12-26_listings.csv.gz and barossa-valley_2012-12-26_listings.csv
# Downloaded barossa-valley_2012-12-26_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-26_reviews.csv.gz and barossa-valley_2012-12-26_reviews.csv
# Downloaded barossa-valley_2012-12-27_listings.csv.gz
# Removed invalid barossa-valley_2012-12-27_listings.csv.gz and barossa-valley_2012-12-27_listings.csv
# Downloaded barossa-valley_2012-12-27_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-27_reviews.csv.gz and barossa-valley_2012-12-27_reviews.csv
# Downloaded barossa-valley_2012-12-28_listings.csv.gz
# Removed invalid barossa-valley_2012-12-28_listings.csv.gz and barossa-valley_2012-12-28_listings.csv
# Downloaded barossa-valley_2012-12-28_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-28_reviews.csv.gz and barossa-valley_2012-12-28_reviews.csv
# Downloaded barossa-valley_2012-12-29_listings.csv.gz
# Removed invalid barossa-valley_2012-12-29_listings.csv.gz and barossa-valley_2012-12-29_listings.csv
# Downloaded barossa-valley_2012-12-29_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-29_reviews.csv.gz and barossa-valley_2012-12-29_reviews.csv
# Downloaded barossa-valley_2012-12-30_listings.csv.gz
# Removed invalid barossa-valley_2012-12-30_listings.csv.gz and barossa-valley_2012-12-30_listings.csv
# Downloaded barossa-valley_2012-12-30_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-30_reviews.csv.gz and barossa-valley_2012-12-30_reviews.csv
# Downloaded barossa-valley_2012-12-31_listings.csv.gz
# Removed invalid barossa-valley_2012-12-31_listings.csv.gz and barossa-valley_2012-12-31_listings.csv
# Downloaded barossa-valley_2012-12-31_reviews.csv.gz
# Removed invalid barossa-valley_2012-12-31_reviews.csv.gz and barossa-valley_2012-12-31_reviews.csv
# Downloaded barossa-valley_2013-01-01_listings.csv.gz
# Removed invalid barossa-valley_2013-01-01_listings.csv.gz and barossa-valley_2013-01-01_listings.csv
# Downloaded barossa-valley_2013-01-01_reviews.csv.gz
# Removed invalid barossa-valley_2013-01-01_reviews.csv.gz and barossa-valley_2013-01-01_reviews.csv
# Downloaded barossa-valley_2013-01-02_listings.csv.gz
# Removed invalid barossa-valley_2013-01-02_listings.csv.gz and barossa-valley_2013-01-02_listings.csv
# Downloaded barossa-valley_2013-01-02_reviews.csv.gz
# Removed invalid barossa-valley_2013-01-02_reviews.csv.gz and barossa-valley_2013-01-02_reviews.csv
# Downloaded barossa-valley_2013-01-03_listings.csv.gz
# Removed invalid barossa-valley_2013-01-03_listings.csv.gz and barossa-valley_2013-01-03_listings.csv
# Downloaded barossa-valley_2013-01-03_reviews.csv.gz
# Removed invalid barossa-valley_2013-01-03_reviews.csv.gz and barossa-valley_2013-01-03_reviews.csv
# Downloaded barossa-valley_2013-01-04_listings.csv.gz
# Removed invalid barossa-valley_2013-01-04_listings.csv.gz and barossa-valley_2013-01-04_listings.csv
# Downloaded barossa-valley_2013-01-04_reviews.csv.gz
# Removed invalid barossa-valley_2013-01-04_reviews.csv.gz and barossa-valley_2013-01-04_reviews.csv
# Downloaded barossa-valley_2013-01-05_listings.csv.gz
# ...
# Downloaded barossa-valley_2024-03-11_reviews.csv.gz
# Removed invalid barossa-valley_2024-03-11_reviews.csv.gz and barossa-valley_2024-03-11_reviews.csv
# Downloaded barossa-valley_2024-03-12_listings.csv.gz
# Removed invalid barossa-valley_2024-03-12_listings.csv.gz and barossa-valley_2024-03-12_listings.csv
# Downloaded barossa-valley_2024-03-12_reviews.csv.gz
# Removed invalid barossa-valley_2024-03-12_reviews.csv.gz and barossa-valley_2024-03-12_reviews.csv
# Downloaded barossa-valley_2024-03-13_listings.csv.gz
# Removed invalid barossa-valley_2024-03-13_listings.csv.gz and barossa-valley_2024-03-13_listings.csv
# Downloaded barossa-valley_2024-03-13_reviews.csv.gz
# Removed invalid barossa-valley_2024-03-13_reviews.csv.gz and barossa-valley_2024-03-13_reviews.csv
# Downloaded barossa-valley_2024-03-14_listings.csv.gz
# Removed invalid barossa-valley_2024-03-14_listings.csv.gz and barossa-valley_2024-03-14_listings.csv
# Downloaded barossa-valley_2024-03-14_reviews.csv.gz
# Removed invalid barossa-valley_2024-03-14_reviews.csv.gz and barossa-valley_2024-03-14_reviews.csv
# Downloaded barossa-valley_2024-03-15_listings.csv.gz
# Removed invalid barossa-valley_2024-03-15_listings.csv.gz and barossa-valley_2024-03-15_listings.csv
# Downloaded barossa-valley_2024-03-15_reviews.csv.gz
# Removed invalid barossa-valley_2024-03-15_reviews.csv.gz and barossa-valley_2024-03-15_reviews.csv
# Downloaded barossa-valley_2024-03-16_listings.csv.gz
# Removed invalid barossa-valley_2024-03-16_listings.csv.gz and barossa-valley_2024-03-16_listings.csv
# Downloaded barossa-valley_2024-03-16_reviews.csv.gz
# Removed invalid barossa-valley_2024-03-16_reviews.csv.gz and barossa-valley_2024-03-16_reviews.csv
# Downloaded barossa-valley_2024-03-17_listings.csv.gz
# Removed invalid barossa-valley_2024-03-17_listings.csv.gz and barossa-valley_2024-03-17_listings.csv
# Downloaded barossa-valley_2024-03-17_reviews.csv.gz
# Removed invalid barossa-valley_2024-03-17_reviews.csv.gz and barossa-valley_2024-03-17_reviews.csv
# Downloaded barossa-valley_2024-03-18_listings.csv.gz
# Removed invalid barossa-valley_2024-03-18_listings.csv.gz and barossa-valley_2024-03-18_listings.csv
# Downloaded barossa-valley_2024-03-18_reviews.csv.gz
# Removed invalid barossa-valley_2024-03-18_reviews.csv.gz and barossa-valley_2024-03-18_reviews.csv
# Downloaded barossa-valley_2024-03-19_listings.csv.gz
# Removed invalid barossa-valley_2024-03-19_listings.csv.gz and barossa-valley_2024-03-19_listings.csv
# Downloaded barossa-valley_2024-03-19_reviews.csv.gz
# Removed invalid barossa-valley_2024-03-19_reviews.csv.gz and barossa-valley_2024-03-19_reviews.csv
# Downloaded barossa-valley_2024-03-20_listings.csv.gz
# Removed invalid barossa-valley_2024-03-20_listings.csv.gz and barossa-valley_2024-03-20_listings.csv
# Downloaded barossa-valley_2024-03-20_reviews.csv.gz
# Removed invalid barossa-valley_2024-03-20_reviews.csv.gz and barossa-valley_2024-03-20_reviews.csv
# Downloaded barossa-valley_2024-03-21_listings.csv.gz
# Removed invalid barossa-valley_2024-03-21_listings.csv.gz and barossa-valley_2024-03-21_listings.csv
# Downloaded barossa-valley_2024-03-21_reviews.csv.gz
# Removed invalid barossa-valley_2024-03-21_reviews.csv.gz and barossa-valley_2024-03-21_reviews.csv
# Downloaded barossa-valley_2024-03-22_listings.csv.gz
# Removed invalid barossa-valley_2024-03-22_listings.csv.gz and barossa-valley_2024-03-22_listings.csv
# Downloaded barossa-valley_2024-03-22_reviews.csv.gz
# Removed invalid barossa-valley_2024-03-22_reviews.csv.gz and barossa-valley_2024-03-22_reviews.csv
# Downloaded barossa-valley_2024-03-23_listings.csv.gz
# Removed invalid barossa-valley_2024-03-23_listings.csv.gz and barossa-valley_2024-03-23_listings.csv
# Downloaded barossa-valley_2024-03-23_reviews.csv.gz
# Removed invalid barossa-valley_2024-03-23_reviews.csv.gz and barossa-valley_2024-03-23_reviews.csv
# Downloaded barossa-valley_2024-03-24_listings.csv.gz
# Removed invalid barossa-valley_2024-03-24_listings.csv.gz and barossa-valley_2024-03-24_listings.csv
# Downloaded barossa-valley_2024-03-24_reviews.csv.gz
# Removed invalid barossa-valley_2024-03-24_reviews.csv.gz and barossa-valley_2024-03-24_reviews.csv
# Downloaded barossa-valley_2024-03-25_listings.csv.gz
# Removed invalid barossa-valley_2024-03-25_listings.csv.gz and barossa-valley_2024-03-25_listings.csv
# Downloaded barossa-valley_2024-03-25_reviews.csv.gz
# Removed invalid barossa-valley_2024-03-25_reviews.csv.gz and barossa-valley_2024-03-25_reviews.csv
# Downloaded barossa-valley_2024-03-26_listings.csv.gz
# Removed invalid barossa-valley_2024-03-26_listings.csv.gz and barossa-valley_2024-03-26_listings.csv
# Downloaded barossa-valley_2024-03-26_reviews.csv.gz
# Removed invalid barossa-valley_2024-03-26_reviews.csv.gz and barossa-valley_2024-03-26_reviews.csv
# Downloaded barossa-valley_2024-03-27_listings.csv.gz
# Removed invalid barossa-valley_2024-03-27_listings.csv.gz and barossa-valley_2024-03-27_listings.csv
# Downloaded barossa-valley_2024-03-27_reviews.csv.gz
# Removed invalid barossa-valley_2024-03-27_reviews.csv.gz and barossa-valley_2024-03-27_reviews.csv
# Downloaded barossa-valley_2024-03-28_listings.csv.gz
# Removed invalid barossa-valley_2024-03-28_listings.csv.gz and barossa-valley_2024-03-28_listings.csv
# Downloaded barossa-valley_2024-03-28_reviews.csv.gz
# Removed invalid barossa-valley_2024-03-28_reviews.csv.gz and barossa-valley_2024-03-28_reviews.csv
# Downloaded barossa-valley_2024-03-29_listings.csv.gz
# Unzipped to barossa-valley_2024-03-29_listings.csv
# Downloaded barossa-valley_2024-03-29_reviews.csv.gz
# Unzipped to barossa-valley_2024-03-29_reviews.csv
# Downloaded barossa-valley_2024-03-30_listings.csv.gz
# Removed invalid barossa-valley_2024-03-30_listings.csv.gz and barossa-valley_2024-03-30_listings.csv
# Downloaded barossa-valley_2024-03-30_reviews.csv.gz
# Removed invalid barossa-valley_2024-03-30_reviews.csv.gz and barossa-valley_2024-03-30_reviews.csv
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~/anaconda3/envs/data_scraping/lib/python3.12/site-packages/urllib3/connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/site-packages/urllib3/connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461 try:
# --> 462     httplib_response = conn.getresponse()
#     463 except BaseException as e:
#     464     # Remove the TypeError from the exception chain in
#     465     # Python 3 (including for exceptions like SystemExit).
#     466     # Otherwise it looks like a bug in the code.
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/http/client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~/anaconda3/envs/data_scraping/lib/python3.12/site-packages/requests/adapters.py:439, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 if not chunked:
# --> 439     resp = conn.urlopen(
#     440         method=request.method,
#     441         url=url,
#     442         body=request.body,
#     443         headers=request.headers,
#     444         redirect=False,
#     445         assert_same_host=False,
#     446         preload_content=False,
#     447         decode_content=False,
#     448         retries=self.max_retries,
#     449         timeout=timeout
#     450     )
#     452 # Send the request.
#     453 else:
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/site-packages/urllib3/connectionpool.py:801, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     799     e = ProtocolError("Connection aborted.", e)
# --> 801 retries = retries.increment(
#     802     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     803 )
#     804 retries.sleep()
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/site-packages/urllib3/util/retry.py:552, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     551 if read is False or not self._is_method_retryable(method):
# --> 552     raise six.reraise(type(error), error, _stacktrace)
#     553 elif read is not None:
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/site-packages/urllib3/packages/six.py:769, in reraise(tp, value, tb)
#     768 if value.__traceback__ is not tb:
# --> 769     raise value.with_traceback(tb)
#     770 raise value
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/site-packages/urllib3/connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/site-packages/urllib3/connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461 try:
# --> 462     httplib_response = conn.getresponse()
#     463 except BaseException as e:
#     464     # Remove the TypeError from the exception chain in
#     465     # Python 3 (including for exceptions like SystemExit).
#     466     # Otherwise it looks like a bug in the code.
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/http/client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[29], line 11
#       9 for affix in [affix_listings, affix_reviews]:
#      10     url = f'{prefix}/{location}/{date}/{affix}'
# ---> 11     res = requests.get(url)
#      13     # download .csv.gz
#      14     name = f'{location.split('/')[-1]}_{date}_{affix.split('/')[-1]}'
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/site-packages/requests/api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/site-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/site-packages/requests/sessions.py:542, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     537 send_kwargs = {
#     538     'timeout': timeout,
#     539     'allow_redirects': allow_redirects,
#     540 }
#     541 send_kwargs.update(settings)
# --> 542 resp = self.send(prep, **send_kwargs)
#     544 return resp
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/site-packages/requests/sessions.py:655, in Session.send(self, request, **kwargs)
#     652 start = preferred_clock()
#     654 # Send the request
# --> 655 r = adapter.send(request, **kwargs)
#     657 # Total elapsed time of the request (approximately)
#     658 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/site-packages/requests/adapters.py:498, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     495             raise
#     497 except (ProtocolError, socket.error) as err:
# --> 498     raise ConnectionError(err, request=request)
#     500 except MaxRetryError as e:
#     501     if isinstance(e.reason, ConnectTimeoutError):
#     502         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %% [markdown]
# ## Download from One Location from a Date Range

# %%
# define your data range
start_date = datetime(2014, 5, 10)
end_date = datetime.today()
dates = []
while start_date <= end_date:
    dates.append(start_date.strftime('%Y-%m-%d'))
    start_date += relativedelta(days=1)  # interval


# define your directory to save the data
save_root = '/Users/yifan/Documents/GitHub/datasets/Inside-Airbnb-Australia/Inside-Airbnb-Australia/barwon-south-west'
# create the directory if it doesn't exist
if not os.path.exists(save_root):
    os.makedirs(save_root, exist_ok=True)


# define the location you want to download the data from
location = 'vic/barwon-south-west-vic'


# start to retrieve the data from the defined location across the defined date range
for date in dates:
    for affix in [affix_listings, affix_reviews]:
        url = f'{prefix}/{location}/{date}/{affix}'
        res = requests.get(url)
        # download .csv.gz files
        name = f'{location.split('/')[-1]}_{date}_{affix.split('/')[-1]}'
        with open(os.path.join(save_root, name), 'wb') as f:
            f.write(res.content)
        print(f"Downloaded {name}")
        # try to unzip, delete invalid file if failed
        try: 
            with gzip.open(os.path.join(save_root, name), 'rb') as f_in, \
                open(os.path.join(save_root, name[:-3]), 'wb') as f_out:
                shutil.copyfileobj(f_in, f_out)
            print(f"Unzipped to {name[:-3]}")
        except gzip.BadGzipFile:
            print(f"Removed invalid {name} and {name[:-3]}")
            os.remove(os.path.join(save_root, name))
            os.remove(os.path.join(save_root, name[:-3]))
# Out:
# Downloaded barwon-south-west_2014-05-10_listings.csv.gz
# Removed invalid barwon-south-west_2014-05-10_listings.csv.gz and barwon-south-west_2014-05-10_listings.csv
# Downloaded barwon-south-west_2014-05-10_reviews.csv.gz
# Removed invalid barwon-south-west_2014-05-10_reviews.csv.gz and barwon-south-west_2014-05-10_reviews.csv
# Downloaded barwon-south-west_2014-05-11_listings.csv.gz
# Removed invalid barwon-south-west_2014-05-11_listings.csv.gz and barwon-south-west_2014-05-11_listings.csv
# Downloaded barwon-south-west_2014-05-11_reviews.csv.gz
# Removed invalid barwon-south-west_2014-05-11_reviews.csv.gz and barwon-south-west_2014-05-11_reviews.csv
# Downloaded barwon-south-west_2014-05-12_listings.csv.gz
# Removed invalid barwon-south-west_2014-05-12_listings.csv.gz and barwon-south-west_2014-05-12_listings.csv
# Downloaded barwon-south-west_2014-05-12_reviews.csv.gz
# Removed invalid barwon-south-west_2014-05-12_reviews.csv.gz and barwon-south-west_2014-05-12_reviews.csv
# Downloaded barwon-south-west_2014-05-13_listings.csv.gz
# Removed invalid barwon-south-west_2014-05-13_listings.csv.gz and barwon-south-west_2014-05-13_listings.csv
# Downloaded barwon-south-west_2014-05-13_reviews.csv.gz
# Removed invalid barwon-south-west_2014-05-13_reviews.csv.gz and barwon-south-west_2014-05-13_reviews.csv
# Downloaded barwon-south-west_2014-05-14_listings.csv.gz
# Removed invalid barwon-south-west_2014-05-14_listings.csv.gz and barwon-south-west_2014-05-14_listings.csv
# Downloaded barwon-south-west_2014-05-14_reviews.csv.gz
# Removed invalid barwon-south-west_2014-05-14_reviews.csv.gz and barwon-south-west_2014-05-14_reviews.csv
# Downloaded barwon-south-west_2014-05-15_listings.csv.gz
# Removed invalid barwon-south-west_2014-05-15_listings.csv.gz and barwon-south-west_2014-05-15_listings.csv
# Downloaded barwon-south-west_2014-05-15_reviews.csv.gz
# Removed invalid barwon-south-west_2014-05-15_reviews.csv.gz and barwon-south-west_2014-05-15_reviews.csv
# Downloaded barwon-south-west_2014-05-16_listings.csv.gz
# Removed invalid barwon-south-west_2014-05-16_listings.csv.gz and barwon-south-west_2014-05-16_listings.csv
# Downloaded barwon-south-west_2014-05-16_reviews.csv.gz
# Removed invalid barwon-south-west_2014-05-16_reviews.csv.gz and barwon-south-west_2014-05-16_reviews.csv
# Downloaded barwon-south-west_2014-05-17_listings.csv.gz
# Removed invalid barwon-south-west_2014-05-17_listings.csv.gz and barwon-south-west_2014-05-17_listings.csv
# Downloaded barwon-south-west_2014-05-17_reviews.csv.gz
# Removed invalid barwon-south-west_2014-05-17_reviews.csv.gz and barwon-south-west_2014-05-17_reviews.csv
# Downloaded barwon-south-west_2014-05-18_listings.csv.gz
# Removed invalid barwon-south-west_2014-05-18_listings.csv.gz and barwon-south-west_2014-05-18_listings.csv
# Downloaded barwon-south-west_2014-05-18_reviews.csv.gz
# Removed invalid barwon-south-west_2014-05-18_reviews.csv.gz and barwon-south-west_2014-05-18_reviews.csv
# Downloaded barwon-south-west_2014-05-19_listings.csv.gz
# Removed invalid barwon-south-west_2014-05-19_listings.csv.gz and barwon-south-west_2014-05-19_listings.csv
# Downloaded barwon-south-west_2014-05-19_reviews.csv.gz
# Removed invalid barwon-south-west_2014-05-19_reviews.csv.gz and barwon-south-west_2014-05-19_reviews.csv
# Downloaded barwon-south-west_2014-05-20_listings.csv.gz
# Removed invalid barwon-south-west_2014-05-20_listings.csv.gz and barwon-south-west_2014-05-20_listings.csv
# Downloaded barwon-south-west_2014-05-20_reviews.csv.gz
# Removed invalid barwon-south-west_2014-05-20_reviews.csv.gz and barwon-south-west_2014-05-20_reviews.csv
# Downloaded barwon-south-west_2014-05-21_listings.csv.gz
# Removed invalid barwon-south-west_2014-05-21_listings.csv.gz and barwon-south-west_2014-05-21_listings.csv
# Downloaded barwon-south-west_2014-05-21_reviews.csv.gz
# Removed invalid barwon-south-west_2014-05-21_reviews.csv.gz and barwon-south-west_2014-05-21_reviews.csv
# Downloaded barwon-south-west_2014-05-22_listings.csv.gz
# Removed invalid barwon-south-west_2014-05-22_listings.csv.gz and barwon-south-west_2014-05-22_listings.csv
# Downloaded barwon-south-west_2014-05-22_reviews.csv.gz
# Removed invalid barwon-south-west_2014-05-22_reviews.csv.gz and barwon-south-west_2014-05-22_reviews.csv
# Downloaded barwon-south-west_2014-05-23_listings.csv.gz
# Removed invalid barwon-south-west_2014-05-23_listings.csv.gz and barwon-south-west_2014-05-23_listings.csv
# Downloaded barwon-south-west_2014-05-23_reviews.csv.gz
# Removed invalid barwon-south-west_2014-05-23_reviews.csv.gz and barwon-south-west_2014-05-23_reviews.csv
# Downloaded barwon-south-west_2014-05-24_listings.csv.gz
# Removed invalid barwon-south-west_2014-05-24_listings.csv.gz and barwon-south-west_2014-05-24_listings.csv
# Downloaded barwon-south-west_2014-05-24_reviews.csv.gz
# Removed invalid barwon-south-west_2014-05-24_reviews.csv.gz and barwon-south-west_2014-05-24_reviews.csv
# Downloaded barwon-south-west_2014-05-25_listings.csv.gz
# Removed invalid barwon-south-west_2014-05-25_listings.csv.gz and barwon-south-west_2014-05-25_listings.csv
# Downloaded barwon-south-west_2014-05-25_reviews.csv.gz
# Removed invalid barwon-south-west_2014-05-25_reviews.csv.gz and barwon-south-west_2014-05-25_reviews.csv
# Downloaded barwon-south-west_2014-05-26_listings.csv.gz
# Removed invalid barwon-south-west_2014-05-26_listings.csv.gz and barwon-south-west_2014-05-26_listings.csv
# Downloaded barwon-south-west_2014-05-26_reviews.csv.gz
# Removed invalid barwon-south-west_2014-05-26_reviews.csv.gz and barwon-south-west_2014-05-26_reviews.csv
# Downloaded barwon-south-west_2014-05-27_listings.csv.gz
# Removed invalid barwon-south-west_2014-05-27_listings.csv.gz and barwon-south-west_2014-05-27_listings.csv
# Downloaded barwon-south-west_2014-05-27_reviews.csv.gz
# Removed invalid barwon-south-west_2014-05-27_reviews.csv.gz and barwon-south-west_2014-05-27_reviews.csv
# Downloaded barwon-south-west_2014-05-28_listings.csv.gz
# Removed invalid barwon-south-west_2014-05-28_listings.csv.gz and barwon-south-west_2014-05-28_listings.csv
# Downloaded barwon-south-west_2014-05-28_reviews.csv.gz
# Removed invalid barwon-south-west_2014-05-28_reviews.csv.gz and barwon-south-west_2014-05-28_reviews.csv
# Downloaded barwon-south-west_2014-05-29_listings.csv.gz
# Removed invalid barwon-south-west_2014-05-29_listings.csv.gz and barwon-south-west_2014-05-29_listings.csv
# Downloaded barwon-south-west_2014-05-29_reviews.csv.gz
# Removed invalid barwon-south-west_2014-05-29_reviews.csv.gz and barwon-south-west_2014-05-29_reviews.csv
# Downloaded barwon-south-west_2014-05-30_listings.csv.gz
# Removed invalid barwon-south-west_2014-05-30_listings.csv.gz and barwon-south-west_2014-05-30_listings.csv
# Downloaded barwon-south-west_2014-05-30_reviews.csv.gz
# Removed invalid barwon-south-west_2014-05-30_reviews.csv.gz and barwon-south-west_2014-05-30_reviews.csv
# Downloaded barwon-south-west_2014-05-31_listings.csv.gz
# Removed invalid barwon-south-west_2014-05-31_listings.csv.gz and barwon-south-west_2014-05-31_listings.csv
# Downloaded barwon-south-west_2014-05-31_reviews.csv.gz
# Removed invalid barwon-south-west_2014-05-31_reviews.csv.gz and barwon-south-west_2014-05-31_reviews.csv
# Downloaded barwon-south-west_2014-06-01_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-01_listings.csv.gz and barwon-south-west_2014-06-01_listings.csv
# Downloaded barwon-south-west_2014-06-01_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-01_reviews.csv.gz and barwon-south-west_2014-06-01_reviews.csv
# Downloaded barwon-south-west_2014-06-02_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-02_listings.csv.gz and barwon-south-west_2014-06-02_listings.csv
# Downloaded barwon-south-west_2014-06-02_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-02_reviews.csv.gz and barwon-south-west_2014-06-02_reviews.csv
# Downloaded barwon-south-west_2014-06-03_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-03_listings.csv.gz and barwon-south-west_2014-06-03_listings.csv
# Downloaded barwon-south-west_2014-06-03_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-03_reviews.csv.gz and barwon-south-west_2014-06-03_reviews.csv
# Downloaded barwon-south-west_2014-06-04_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-04_listings.csv.gz and barwon-south-west_2014-06-04_listings.csv
# Downloaded barwon-south-west_2014-06-04_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-04_reviews.csv.gz and barwon-south-west_2014-06-04_reviews.csv
# Downloaded barwon-south-west_2014-06-05_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-05_listings.csv.gz and barwon-south-west_2014-06-05_listings.csv
# Downloaded barwon-south-west_2014-06-05_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-05_reviews.csv.gz and barwon-south-west_2014-06-05_reviews.csv
# Downloaded barwon-south-west_2014-06-06_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-06_listings.csv.gz and barwon-south-west_2014-06-06_listings.csv
# Downloaded barwon-south-west_2014-06-06_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-06_reviews.csv.gz and barwon-south-west_2014-06-06_reviews.csv
# Downloaded barwon-south-west_2014-06-07_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-07_listings.csv.gz and barwon-south-west_2014-06-07_listings.csv
# Downloaded barwon-south-west_2014-06-07_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-07_reviews.csv.gz and barwon-south-west_2014-06-07_reviews.csv
# Downloaded barwon-south-west_2014-06-08_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-08_listings.csv.gz and barwon-south-west_2014-06-08_listings.csv
# Downloaded barwon-south-west_2014-06-08_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-08_reviews.csv.gz and barwon-south-west_2014-06-08_reviews.csv
# Downloaded barwon-south-west_2014-06-09_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-09_listings.csv.gz and barwon-south-west_2014-06-09_listings.csv
# Downloaded barwon-south-west_2014-06-09_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-09_reviews.csv.gz and barwon-south-west_2014-06-09_reviews.csv
# Downloaded barwon-south-west_2014-06-10_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-10_listings.csv.gz and barwon-south-west_2014-06-10_listings.csv
# Downloaded barwon-south-west_2014-06-10_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-10_reviews.csv.gz and barwon-south-west_2014-06-10_reviews.csv
# Downloaded barwon-south-west_2014-06-11_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-11_listings.csv.gz and barwon-south-west_2014-06-11_listings.csv
# Downloaded barwon-south-west_2014-06-11_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-11_reviews.csv.gz and barwon-south-west_2014-06-11_reviews.csv
# Downloaded barwon-south-west_2014-06-12_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-12_listings.csv.gz and barwon-south-west_2014-06-12_listings.csv
# Downloaded barwon-south-west_2014-06-12_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-12_reviews.csv.gz and barwon-south-west_2014-06-12_reviews.csv
# Downloaded barwon-south-west_2014-06-13_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-13_listings.csv.gz and barwon-south-west_2014-06-13_listings.csv
# Downloaded barwon-south-west_2014-06-13_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-13_reviews.csv.gz and barwon-south-west_2014-06-13_reviews.csv
# Downloaded barwon-south-west_2014-06-14_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-14_listings.csv.gz and barwon-south-west_2014-06-14_listings.csv
# Downloaded barwon-south-west_2014-06-14_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-14_reviews.csv.gz and barwon-south-west_2014-06-14_reviews.csv
# Downloaded barwon-south-west_2014-06-15_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-15_listings.csv.gz and barwon-south-west_2014-06-15_listings.csv
# Downloaded barwon-south-west_2014-06-15_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-15_reviews.csv.gz and barwon-south-west_2014-06-15_reviews.csv
# Downloaded barwon-south-west_2014-06-16_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-16_listings.csv.gz and barwon-south-west_2014-06-16_listings.csv
# Downloaded barwon-south-west_2014-06-16_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-16_reviews.csv.gz and barwon-south-west_2014-06-16_reviews.csv
# Downloaded barwon-south-west_2014-06-17_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-17_listings.csv.gz and barwon-south-west_2014-06-17_listings.csv
# Downloaded barwon-south-west_2014-06-17_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-17_reviews.csv.gz and barwon-south-west_2014-06-17_reviews.csv
# Downloaded barwon-south-west_2014-06-18_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-18_listings.csv.gz and barwon-south-west_2014-06-18_listings.csv
# Downloaded barwon-south-west_2014-06-18_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-18_reviews.csv.gz and barwon-south-west_2014-06-18_reviews.csv
# Downloaded barwon-south-west_2014-06-19_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-19_listings.csv.gz and barwon-south-west_2014-06-19_listings.csv
# Downloaded barwon-south-west_2014-06-19_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-19_reviews.csv.gz and barwon-south-west_2014-06-19_reviews.csv
# Downloaded barwon-south-west_2014-06-20_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-20_listings.csv.gz and barwon-south-west_2014-06-20_listings.csv
# Downloaded barwon-south-west_2014-06-20_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-20_reviews.csv.gz and barwon-south-west_2014-06-20_reviews.csv
# Downloaded barwon-south-west_2014-06-21_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-21_listings.csv.gz and barwon-south-west_2014-06-21_listings.csv
# Downloaded barwon-south-west_2014-06-21_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-21_reviews.csv.gz and barwon-south-west_2014-06-21_reviews.csv
# Downloaded barwon-south-west_2014-06-22_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-22_listings.csv.gz and barwon-south-west_2014-06-22_listings.csv
# Downloaded barwon-south-west_2014-06-22_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-22_reviews.csv.gz and barwon-south-west_2014-06-22_reviews.csv
# Downloaded barwon-south-west_2014-06-23_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-23_listings.csv.gz and barwon-south-west_2014-06-23_listings.csv
# Downloaded barwon-south-west_2014-06-23_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-23_reviews.csv.gz and barwon-south-west_2014-06-23_reviews.csv
# Downloaded barwon-south-west_2014-06-24_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-24_listings.csv.gz and barwon-south-west_2014-06-24_listings.csv
# Downloaded barwon-south-west_2014-06-24_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-24_reviews.csv.gz and barwon-south-west_2014-06-24_reviews.csv
# Downloaded barwon-south-west_2014-06-25_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-25_listings.csv.gz and barwon-south-west_2014-06-25_listings.csv
# Downloaded barwon-south-west_2014-06-25_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-25_reviews.csv.gz and barwon-south-west_2014-06-25_reviews.csv
# Downloaded barwon-south-west_2014-06-26_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-26_listings.csv.gz and barwon-south-west_2014-06-26_listings.csv
# Downloaded barwon-south-west_2014-06-26_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-26_reviews.csv.gz and barwon-south-west_2014-06-26_reviews.csv
# Downloaded barwon-south-west_2014-06-27_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-27_listings.csv.gz and barwon-south-west_2014-06-27_listings.csv
# Downloaded barwon-south-west_2014-06-27_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-27_reviews.csv.gz and barwon-south-west_2014-06-27_reviews.csv
# Downloaded barwon-south-west_2014-06-28_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-28_listings.csv.gz and barwon-south-west_2014-06-28_listings.csv
# Downloaded barwon-south-west_2014-06-28_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-28_reviews.csv.gz and barwon-south-west_2014-06-28_reviews.csv
# Downloaded barwon-south-west_2014-06-29_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-29_listings.csv.gz and barwon-south-west_2014-06-29_listings.csv
# Downloaded barwon-south-west_2014-06-29_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-29_reviews.csv.gz and barwon-south-west_2014-06-29_reviews.csv
# Downloaded barwon-south-west_2014-06-30_listings.csv.gz
# Removed invalid barwon-south-west_2014-06-30_listings.csv.gz and barwon-south-west_2014-06-30_listings.csv
# Downloaded barwon-south-west_2014-06-30_reviews.csv.gz
# Removed invalid barwon-south-west_2014-06-30_reviews.csv.gz and barwon-south-west_2014-06-30_reviews.csv
# Downloaded barwon-south-west_2014-07-01_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-01_listings.csv.gz and barwon-south-west_2014-07-01_listings.csv
# Downloaded barwon-south-west_2014-07-01_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-01_reviews.csv.gz and barwon-south-west_2014-07-01_reviews.csv
# Downloaded barwon-south-west_2014-07-02_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-02_listings.csv.gz and barwon-south-west_2014-07-02_listings.csv
# Downloaded barwon-south-west_2014-07-02_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-02_reviews.csv.gz and barwon-south-west_2014-07-02_reviews.csv
# Downloaded barwon-south-west_2014-07-03_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-03_listings.csv.gz and barwon-south-west_2014-07-03_listings.csv
# Downloaded barwon-south-west_2014-07-03_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-03_reviews.csv.gz and barwon-south-west_2014-07-03_reviews.csv
# Downloaded barwon-south-west_2014-07-04_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-04_listings.csv.gz and barwon-south-west_2014-07-04_listings.csv
# Downloaded barwon-south-west_2014-07-04_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-04_reviews.csv.gz and barwon-south-west_2014-07-04_reviews.csv
# Downloaded barwon-south-west_2014-07-05_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-05_listings.csv.gz and barwon-south-west_2014-07-05_listings.csv
# Downloaded barwon-south-west_2014-07-05_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-05_reviews.csv.gz and barwon-south-west_2014-07-05_reviews.csv
# Downloaded barwon-south-west_2014-07-06_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-06_listings.csv.gz and barwon-south-west_2014-07-06_listings.csv
# Downloaded barwon-south-west_2014-07-06_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-06_reviews.csv.gz and barwon-south-west_2014-07-06_reviews.csv
# Downloaded barwon-south-west_2014-07-07_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-07_listings.csv.gz and barwon-south-west_2014-07-07_listings.csv
# Downloaded barwon-south-west_2014-07-07_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-07_reviews.csv.gz and barwon-south-west_2014-07-07_reviews.csv
# Downloaded barwon-south-west_2014-07-08_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-08_listings.csv.gz and barwon-south-west_2014-07-08_listings.csv
# Downloaded barwon-south-west_2014-07-08_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-08_reviews.csv.gz and barwon-south-west_2014-07-08_reviews.csv
# Downloaded barwon-south-west_2014-07-09_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-09_listings.csv.gz and barwon-south-west_2014-07-09_listings.csv
# Downloaded barwon-south-west_2014-07-09_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-09_reviews.csv.gz and barwon-south-west_2014-07-09_reviews.csv
# Downloaded barwon-south-west_2014-07-10_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-10_listings.csv.gz and barwon-south-west_2014-07-10_listings.csv
# Downloaded barwon-south-west_2014-07-10_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-10_reviews.csv.gz and barwon-south-west_2014-07-10_reviews.csv
# Downloaded barwon-south-west_2014-07-11_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-11_listings.csv.gz and barwon-south-west_2014-07-11_listings.csv
# Downloaded barwon-south-west_2014-07-11_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-11_reviews.csv.gz and barwon-south-west_2014-07-11_reviews.csv
# Downloaded barwon-south-west_2014-07-12_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-12_listings.csv.gz and barwon-south-west_2014-07-12_listings.csv
# Downloaded barwon-south-west_2014-07-12_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-12_reviews.csv.gz and barwon-south-west_2014-07-12_reviews.csv
# Downloaded barwon-south-west_2014-07-13_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-13_listings.csv.gz and barwon-south-west_2014-07-13_listings.csv
# Downloaded barwon-south-west_2014-07-13_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-13_reviews.csv.gz and barwon-south-west_2014-07-13_reviews.csv
# Downloaded barwon-south-west_2014-07-14_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-14_listings.csv.gz and barwon-south-west_2014-07-14_listings.csv
# Downloaded barwon-south-west_2014-07-14_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-14_reviews.csv.gz and barwon-south-west_2014-07-14_reviews.csv
# Downloaded barwon-south-west_2014-07-15_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-15_listings.csv.gz and barwon-south-west_2014-07-15_listings.csv
# Downloaded barwon-south-west_2014-07-15_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-15_reviews.csv.gz and barwon-south-west_2014-07-15_reviews.csv
# Downloaded barwon-south-west_2014-07-16_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-16_listings.csv.gz and barwon-south-west_2014-07-16_listings.csv
# Downloaded barwon-south-west_2014-07-16_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-16_reviews.csv.gz and barwon-south-west_2014-07-16_reviews.csv
# Downloaded barwon-south-west_2014-07-17_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-17_listings.csv.gz and barwon-south-west_2014-07-17_listings.csv
# Downloaded barwon-south-west_2014-07-17_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-17_reviews.csv.gz and barwon-south-west_2014-07-17_reviews.csv
# Downloaded barwon-south-west_2014-07-18_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-18_listings.csv.gz and barwon-south-west_2014-07-18_listings.csv
# Downloaded barwon-south-west_2014-07-18_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-18_reviews.csv.gz and barwon-south-west_2014-07-18_reviews.csv
# Downloaded barwon-south-west_2014-07-19_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-19_listings.csv.gz and barwon-south-west_2014-07-19_listings.csv
# Downloaded barwon-south-west_2014-07-19_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-19_reviews.csv.gz and barwon-south-west_2014-07-19_reviews.csv
# Downloaded barwon-south-west_2014-07-20_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-20_listings.csv.gz and barwon-south-west_2014-07-20_listings.csv
# Downloaded barwon-south-west_2014-07-20_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-20_reviews.csv.gz and barwon-south-west_2014-07-20_reviews.csv
# Downloaded barwon-south-west_2014-07-21_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-21_listings.csv.gz and barwon-south-west_2014-07-21_listings.csv
# Downloaded barwon-south-west_2014-07-21_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-21_reviews.csv.gz and barwon-south-west_2014-07-21_reviews.csv
# Downloaded barwon-south-west_2014-07-22_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-22_listings.csv.gz and barwon-south-west_2014-07-22_listings.csv
# Downloaded barwon-south-west_2014-07-22_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-22_reviews.csv.gz and barwon-south-west_2014-07-22_reviews.csv
# Downloaded barwon-south-west_2014-07-23_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-23_listings.csv.gz and barwon-south-west_2014-07-23_listings.csv
# Downloaded barwon-south-west_2014-07-23_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-23_reviews.csv.gz and barwon-south-west_2014-07-23_reviews.csv
# Downloaded barwon-south-west_2014-07-24_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-24_listings.csv.gz and barwon-south-west_2014-07-24_listings.csv
# Downloaded barwon-south-west_2014-07-24_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-24_reviews.csv.gz and barwon-south-west_2014-07-24_reviews.csv
# Downloaded barwon-south-west_2014-07-25_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-25_listings.csv.gz and barwon-south-west_2014-07-25_listings.csv
# Downloaded barwon-south-west_2014-07-25_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-25_reviews.csv.gz and barwon-south-west_2014-07-25_reviews.csv
# Downloaded barwon-south-west_2014-07-26_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-26_listings.csv.gz and barwon-south-west_2014-07-26_listings.csv
# Downloaded barwon-south-west_2014-07-26_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-26_reviews.csv.gz and barwon-south-west_2014-07-26_reviews.csv
# Downloaded barwon-south-west_2014-07-27_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-27_listings.csv.gz and barwon-south-west_2014-07-27_listings.csv
# Downloaded barwon-south-west_2014-07-27_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-27_reviews.csv.gz and barwon-south-west_2014-07-27_reviews.csv
# Downloaded barwon-south-west_2014-07-28_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-28_listings.csv.gz and barwon-south-west_2014-07-28_listings.csv
# Downloaded barwon-south-west_2014-07-28_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-28_reviews.csv.gz and barwon-south-west_2014-07-28_reviews.csv
# Downloaded barwon-south-west_2014-07-29_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-29_listings.csv.gz and barwon-south-west_2014-07-29_listings.csv
# Downloaded barwon-south-west_2014-07-29_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-29_reviews.csv.gz and barwon-south-west_2014-07-29_reviews.csv
# Downloaded barwon-south-west_2014-07-30_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-30_listings.csv.gz and barwon-south-west_2014-07-30_listings.csv
# Downloaded barwon-south-west_2014-07-30_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-30_reviews.csv.gz and barwon-south-west_2014-07-30_reviews.csv
# Downloaded barwon-south-west_2014-07-31_listings.csv.gz
# Removed invalid barwon-south-west_2014-07-31_listings.csv.gz and barwon-south-west_2014-07-31_listings.csv
# Downloaded barwon-south-west_2014-07-31_reviews.csv.gz
# Removed invalid barwon-south-west_2014-07-31_reviews.csv.gz and barwon-south-west_2014-07-31_reviews.csv
# Downloaded barwon-south-west_2014-08-01_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-01_listings.csv.gz and barwon-south-west_2014-08-01_listings.csv
# Downloaded barwon-south-west_2014-08-01_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-01_reviews.csv.gz and barwon-south-west_2014-08-01_reviews.csv
# Downloaded barwon-south-west_2014-08-02_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-02_listings.csv.gz and barwon-south-west_2014-08-02_listings.csv
# Downloaded barwon-south-west_2014-08-02_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-02_reviews.csv.gz and barwon-south-west_2014-08-02_reviews.csv
# Downloaded barwon-south-west_2014-08-03_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-03_listings.csv.gz and barwon-south-west_2014-08-03_listings.csv
# Downloaded barwon-south-west_2014-08-03_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-03_reviews.csv.gz and barwon-south-west_2014-08-03_reviews.csv
# Downloaded barwon-south-west_2014-08-04_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-04_listings.csv.gz and barwon-south-west_2014-08-04_listings.csv
# Downloaded barwon-south-west_2014-08-04_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-04_reviews.csv.gz and barwon-south-west_2014-08-04_reviews.csv
# Downloaded barwon-south-west_2014-08-05_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-05_listings.csv.gz and barwon-south-west_2014-08-05_listings.csv
# Downloaded barwon-south-west_2014-08-05_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-05_reviews.csv.gz and barwon-south-west_2014-08-05_reviews.csv
# Downloaded barwon-south-west_2014-08-06_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-06_listings.csv.gz and barwon-south-west_2014-08-06_listings.csv
# Downloaded barwon-south-west_2014-08-06_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-06_reviews.csv.gz and barwon-south-west_2014-08-06_reviews.csv
# Downloaded barwon-south-west_2014-08-07_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-07_listings.csv.gz and barwon-south-west_2014-08-07_listings.csv
# Downloaded barwon-south-west_2014-08-07_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-07_reviews.csv.gz and barwon-south-west_2014-08-07_reviews.csv
# Downloaded barwon-south-west_2014-08-08_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-08_listings.csv.gz and barwon-south-west_2014-08-08_listings.csv
# Downloaded barwon-south-west_2014-08-08_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-08_reviews.csv.gz and barwon-south-west_2014-08-08_reviews.csv
# Downloaded barwon-south-west_2014-08-09_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-09_listings.csv.gz and barwon-south-west_2014-08-09_listings.csv
# Downloaded barwon-south-west_2014-08-09_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-09_reviews.csv.gz and barwon-south-west_2014-08-09_reviews.csv
# Downloaded barwon-south-west_2014-08-10_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-10_listings.csv.gz and barwon-south-west_2014-08-10_listings.csv
# Downloaded barwon-south-west_2014-08-10_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-10_reviews.csv.gz and barwon-south-west_2014-08-10_reviews.csv
# Downloaded barwon-south-west_2014-08-11_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-11_listings.csv.gz and barwon-south-west_2014-08-11_listings.csv
# Downloaded barwon-south-west_2014-08-11_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-11_reviews.csv.gz and barwon-south-west_2014-08-11_reviews.csv
# Downloaded barwon-south-west_2014-08-12_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-12_listings.csv.gz and barwon-south-west_2014-08-12_listings.csv
# Downloaded barwon-south-west_2014-08-12_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-12_reviews.csv.gz and barwon-south-west_2014-08-12_reviews.csv
# Downloaded barwon-south-west_2014-08-13_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-13_listings.csv.gz and barwon-south-west_2014-08-13_listings.csv
# Downloaded barwon-south-west_2014-08-13_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-13_reviews.csv.gz and barwon-south-west_2014-08-13_reviews.csv
# Downloaded barwon-south-west_2014-08-14_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-14_listings.csv.gz and barwon-south-west_2014-08-14_listings.csv
# Downloaded barwon-south-west_2014-08-14_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-14_reviews.csv.gz and barwon-south-west_2014-08-14_reviews.csv
# Downloaded barwon-south-west_2014-08-15_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-15_listings.csv.gz and barwon-south-west_2014-08-15_listings.csv
# Downloaded barwon-south-west_2014-08-15_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-15_reviews.csv.gz and barwon-south-west_2014-08-15_reviews.csv
# Downloaded barwon-south-west_2014-08-16_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-16_listings.csv.gz and barwon-south-west_2014-08-16_listings.csv
# Downloaded barwon-south-west_2014-08-16_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-16_reviews.csv.gz and barwon-south-west_2014-08-16_reviews.csv
# Downloaded barwon-south-west_2014-08-17_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-17_listings.csv.gz and barwon-south-west_2014-08-17_listings.csv
# Downloaded barwon-south-west_2014-08-17_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-17_reviews.csv.gz and barwon-south-west_2014-08-17_reviews.csv
# Downloaded barwon-south-west_2014-08-18_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-18_listings.csv.gz and barwon-south-west_2014-08-18_listings.csv
# Downloaded barwon-south-west_2014-08-18_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-18_reviews.csv.gz and barwon-south-west_2014-08-18_reviews.csv
# Downloaded barwon-south-west_2014-08-19_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-19_listings.csv.gz and barwon-south-west_2014-08-19_listings.csv
# Downloaded barwon-south-west_2014-08-19_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-19_reviews.csv.gz and barwon-south-west_2014-08-19_reviews.csv
# Downloaded barwon-south-west_2014-08-20_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-20_listings.csv.gz and barwon-south-west_2014-08-20_listings.csv
# Downloaded barwon-south-west_2014-08-20_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-20_reviews.csv.gz and barwon-south-west_2014-08-20_reviews.csv
# Downloaded barwon-south-west_2014-08-21_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-21_listings.csv.gz and barwon-south-west_2014-08-21_listings.csv
# Downloaded barwon-south-west_2014-08-21_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-21_reviews.csv.gz and barwon-south-west_2014-08-21_reviews.csv
# Downloaded barwon-south-west_2014-08-22_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-22_listings.csv.gz and barwon-south-west_2014-08-22_listings.csv
# Downloaded barwon-south-west_2014-08-22_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-22_reviews.csv.gz and barwon-south-west_2014-08-22_reviews.csv
# Downloaded barwon-south-west_2014-08-23_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-23_listings.csv.gz and barwon-south-west_2014-08-23_listings.csv
# Downloaded barwon-south-west_2014-08-23_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-23_reviews.csv.gz and barwon-south-west_2014-08-23_reviews.csv
# Downloaded barwon-south-west_2014-08-24_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-24_listings.csv.gz and barwon-south-west_2014-08-24_listings.csv
# Downloaded barwon-south-west_2014-08-24_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-24_reviews.csv.gz and barwon-south-west_2014-08-24_reviews.csv
# Downloaded barwon-south-west_2014-08-25_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-25_listings.csv.gz and barwon-south-west_2014-08-25_listings.csv
# Downloaded barwon-south-west_2014-08-25_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-25_reviews.csv.gz and barwon-south-west_2014-08-25_reviews.csv
# Downloaded barwon-south-west_2014-08-26_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-26_listings.csv.gz and barwon-south-west_2014-08-26_listings.csv
# Downloaded barwon-south-west_2014-08-26_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-26_reviews.csv.gz and barwon-south-west_2014-08-26_reviews.csv
# Downloaded barwon-south-west_2014-08-27_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-27_listings.csv.gz and barwon-south-west_2014-08-27_listings.csv
# Downloaded barwon-south-west_2014-08-27_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-27_reviews.csv.gz and barwon-south-west_2014-08-27_reviews.csv
# Downloaded barwon-south-west_2014-08-28_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-28_listings.csv.gz and barwon-south-west_2014-08-28_listings.csv
# Downloaded barwon-south-west_2014-08-28_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-28_reviews.csv.gz and barwon-south-west_2014-08-28_reviews.csv
# Downloaded barwon-south-west_2014-08-29_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-29_listings.csv.gz and barwon-south-west_2014-08-29_listings.csv
# Downloaded barwon-south-west_2014-08-29_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-29_reviews.csv.gz and barwon-south-west_2014-08-29_reviews.csv
# Downloaded barwon-south-west_2014-08-30_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-30_listings.csv.gz and barwon-south-west_2014-08-30_listings.csv
# Downloaded barwon-south-west_2014-08-30_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-30_reviews.csv.gz and barwon-south-west_2014-08-30_reviews.csv
# Downloaded barwon-south-west_2014-08-31_listings.csv.gz
# Removed invalid barwon-south-west_2014-08-31_listings.csv.gz and barwon-south-west_2014-08-31_listings.csv
# Downloaded barwon-south-west_2014-08-31_reviews.csv.gz
# Removed invalid barwon-south-west_2014-08-31_reviews.csv.gz and barwon-south-west_2014-08-31_reviews.csv
# Downloaded barwon-south-west_2014-09-01_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-01_listings.csv.gz and barwon-south-west_2014-09-01_listings.csv
# Downloaded barwon-south-west_2014-09-01_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-01_reviews.csv.gz and barwon-south-west_2014-09-01_reviews.csv
# Downloaded barwon-south-west_2014-09-02_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-02_listings.csv.gz and barwon-south-west_2014-09-02_listings.csv
# Downloaded barwon-south-west_2014-09-02_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-02_reviews.csv.gz and barwon-south-west_2014-09-02_reviews.csv
# Downloaded barwon-south-west_2014-09-03_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-03_listings.csv.gz and barwon-south-west_2014-09-03_listings.csv
# Downloaded barwon-south-west_2014-09-03_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-03_reviews.csv.gz and barwon-south-west_2014-09-03_reviews.csv
# Downloaded barwon-south-west_2014-09-04_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-04_listings.csv.gz and barwon-south-west_2014-09-04_listings.csv
# Downloaded barwon-south-west_2014-09-04_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-04_reviews.csv.gz and barwon-south-west_2014-09-04_reviews.csv
# Downloaded barwon-south-west_2014-09-05_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-05_listings.csv.gz and barwon-south-west_2014-09-05_listings.csv
# Downloaded barwon-south-west_2014-09-05_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-05_reviews.csv.gz and barwon-south-west_2014-09-05_reviews.csv
# Downloaded barwon-south-west_2014-09-06_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-06_listings.csv.gz and barwon-south-west_2014-09-06_listings.csv
# Downloaded barwon-south-west_2014-09-06_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-06_reviews.csv.gz and barwon-south-west_2014-09-06_reviews.csv
# Downloaded barwon-south-west_2014-09-07_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-07_listings.csv.gz and barwon-south-west_2014-09-07_listings.csv
# Downloaded barwon-south-west_2014-09-07_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-07_reviews.csv.gz and barwon-south-west_2014-09-07_reviews.csv
# Downloaded barwon-south-west_2014-09-08_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-08_listings.csv.gz and barwon-south-west_2014-09-08_listings.csv
# Downloaded barwon-south-west_2014-09-08_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-08_reviews.csv.gz and barwon-south-west_2014-09-08_reviews.csv
# Downloaded barwon-south-west_2014-09-09_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-09_listings.csv.gz and barwon-south-west_2014-09-09_listings.csv
# Downloaded barwon-south-west_2014-09-09_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-09_reviews.csv.gz and barwon-south-west_2014-09-09_reviews.csv
# Downloaded barwon-south-west_2014-09-10_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-10_listings.csv.gz and barwon-south-west_2014-09-10_listings.csv
# Downloaded barwon-south-west_2014-09-10_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-10_reviews.csv.gz and barwon-south-west_2014-09-10_reviews.csv
# Downloaded barwon-south-west_2014-09-11_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-11_listings.csv.gz and barwon-south-west_2014-09-11_listings.csv
# Downloaded barwon-south-west_2014-09-11_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-11_reviews.csv.gz and barwon-south-west_2014-09-11_reviews.csv
# Downloaded barwon-south-west_2014-09-12_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-12_listings.csv.gz and barwon-south-west_2014-09-12_listings.csv
# Downloaded barwon-south-west_2014-09-12_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-12_reviews.csv.gz and barwon-south-west_2014-09-12_reviews.csv
# Downloaded barwon-south-west_2014-09-13_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-13_listings.csv.gz and barwon-south-west_2014-09-13_listings.csv
# Downloaded barwon-south-west_2014-09-13_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-13_reviews.csv.gz and barwon-south-west_2014-09-13_reviews.csv
# Downloaded barwon-south-west_2014-09-14_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-14_listings.csv.gz and barwon-south-west_2014-09-14_listings.csv
# Downloaded barwon-south-west_2014-09-14_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-14_reviews.csv.gz and barwon-south-west_2014-09-14_reviews.csv
# Downloaded barwon-south-west_2014-09-15_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-15_listings.csv.gz and barwon-south-west_2014-09-15_listings.csv
# Downloaded barwon-south-west_2014-09-15_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-15_reviews.csv.gz and barwon-south-west_2014-09-15_reviews.csv
# Downloaded barwon-south-west_2014-09-16_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-16_listings.csv.gz and barwon-south-west_2014-09-16_listings.csv
# Downloaded barwon-south-west_2014-09-16_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-16_reviews.csv.gz and barwon-south-west_2014-09-16_reviews.csv
# Downloaded barwon-south-west_2014-09-17_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-17_listings.csv.gz and barwon-south-west_2014-09-17_listings.csv
# Downloaded barwon-south-west_2014-09-17_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-17_reviews.csv.gz and barwon-south-west_2014-09-17_reviews.csv
# Downloaded barwon-south-west_2014-09-18_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-18_listings.csv.gz and barwon-south-west_2014-09-18_listings.csv
# Downloaded barwon-south-west_2014-09-18_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-18_reviews.csv.gz and barwon-south-west_2014-09-18_reviews.csv
# Downloaded barwon-south-west_2014-09-19_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-19_listings.csv.gz and barwon-south-west_2014-09-19_listings.csv
# Downloaded barwon-south-west_2014-09-19_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-19_reviews.csv.gz and barwon-south-west_2014-09-19_reviews.csv
# Downloaded barwon-south-west_2014-09-20_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-20_listings.csv.gz and barwon-south-west_2014-09-20_listings.csv
# Downloaded barwon-south-west_2014-09-20_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-20_reviews.csv.gz and barwon-south-west_2014-09-20_reviews.csv
# Downloaded barwon-south-west_2014-09-21_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-21_listings.csv.gz and barwon-south-west_2014-09-21_listings.csv
# Downloaded barwon-south-west_2014-09-21_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-21_reviews.csv.gz and barwon-south-west_2014-09-21_reviews.csv
# Downloaded barwon-south-west_2014-09-22_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-22_listings.csv.gz and barwon-south-west_2014-09-22_listings.csv
# Downloaded barwon-south-west_2014-09-22_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-22_reviews.csv.gz and barwon-south-west_2014-09-22_reviews.csv
# Downloaded barwon-south-west_2014-09-23_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-23_listings.csv.gz and barwon-south-west_2014-09-23_listings.csv
# Downloaded barwon-south-west_2014-09-23_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-23_reviews.csv.gz and barwon-south-west_2014-09-23_reviews.csv
# Downloaded barwon-south-west_2014-09-24_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-24_listings.csv.gz and barwon-south-west_2014-09-24_listings.csv
# Downloaded barwon-south-west_2014-09-24_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-24_reviews.csv.gz and barwon-south-west_2014-09-24_reviews.csv
# Downloaded barwon-south-west_2014-09-25_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-25_listings.csv.gz and barwon-south-west_2014-09-25_listings.csv
# Downloaded barwon-south-west_2014-09-25_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-25_reviews.csv.gz and barwon-south-west_2014-09-25_reviews.csv
# Downloaded barwon-south-west_2014-09-26_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-26_listings.csv.gz and barwon-south-west_2014-09-26_listings.csv
# Downloaded barwon-south-west_2014-09-26_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-26_reviews.csv.gz and barwon-south-west_2014-09-26_reviews.csv
# Downloaded barwon-south-west_2014-09-27_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-27_listings.csv.gz and barwon-south-west_2014-09-27_listings.csv
# Downloaded barwon-south-west_2014-09-27_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-27_reviews.csv.gz and barwon-south-west_2014-09-27_reviews.csv
# Downloaded barwon-south-west_2014-09-28_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-28_listings.csv.gz and barwon-south-west_2014-09-28_listings.csv
# Downloaded barwon-south-west_2014-09-28_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-28_reviews.csv.gz and barwon-south-west_2014-09-28_reviews.csv
# Downloaded barwon-south-west_2014-09-29_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-29_listings.csv.gz and barwon-south-west_2014-09-29_listings.csv
# Downloaded barwon-south-west_2014-09-29_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-29_reviews.csv.gz and barwon-south-west_2014-09-29_reviews.csv
# Downloaded barwon-south-west_2014-09-30_listings.csv.gz
# Removed invalid barwon-south-west_2014-09-30_listings.csv.gz and barwon-south-west_2014-09-30_listings.csv
# Downloaded barwon-south-west_2014-09-30_reviews.csv.gz
# Removed invalid barwon-south-west_2014-09-30_reviews.csv.gz and barwon-south-west_2014-09-30_reviews.csv
# Downloaded barwon-south-west_2014-10-01_listings.csv.gz
# Removed invalid barwon-south-west_2014-10-01_listings.csv.gz and barwon-south-west_2014-10-01_listings.csv
# Downloaded barwon-south-west_2014-10-01_reviews.csv.gz
# Removed invalid barwon-south-west_2014-10-01_reviews.csv.gz and barwon-south-west_2014-10-01_reviews.csv
# Downloaded barwon-south-west_2014-10-02_listings.csv.gz
# Removed invalid barwon-south-west_2014-10-02_listings.csv.gz and barwon-south-west_2014-10-02_listings.csv
# Downloaded barwon-south-west_2014-10-02_reviews.csv.gz
# Removed invalid barwon-south-west_2014-10-02_reviews.csv.gz and barwon-south-west_2014-10-02_reviews.csv
# Downloaded barwon-south-west_2014-10-03_listings.csv.gz
# Removed invalid barwon-south-west_2014-10-03_listings.csv.gz and barwon-south-west_2014-10-03_listings.csv
# Downloaded barwon-south-west_2014-10-03_reviews.csv.gz
# Removed invalid barwon-south-west_2014-10-03_reviews.csv.gz and barwon-south-west_2014-10-03_reviews.csv
# Downloaded barwon-south-west_2014-10-04_listings.csv.gz
# Removed invalid barwon-south-west_2014-10-04_listings.csv.gz and barwon-south-west_2014-10-04_listings.csv
# Downloaded barwon-south-west_2014-10-04_reviews.csv.gz
# Removed invalid barwon-south-west_2014-10-04_reviews.csv.gz and barwon-south-west_2014-10-04_reviews.csv
# Downloaded barwon-south-west_2014-10-05_listings.csv.gz
# Removed invalid barwon-south-west_2014-10-05_listings.csv.gz and barwon-south-west_2014-10-05_listings.csv
# ...
# Removed invalid barwon-south-west_2018-05-19_reviews.csv.gz and barwon-south-west_2018-05-19_reviews.csv
# Downloaded barwon-south-west_2018-05-20_listings.csv.gz
# Removed invalid barwon-south-west_2018-05-20_listings.csv.gz and barwon-south-west_2018-05-20_listings.csv
# Downloaded barwon-south-west_2018-05-20_reviews.csv.gz
# Removed invalid barwon-south-west_2018-05-20_reviews.csv.gz and barwon-south-west_2018-05-20_reviews.csv
# Downloaded barwon-south-west_2018-05-21_listings.csv.gz
# Removed invalid barwon-south-west_2018-05-21_listings.csv.gz and barwon-south-west_2018-05-21_listings.csv
# Downloaded barwon-south-west_2018-05-21_reviews.csv.gz
# Removed invalid barwon-south-west_2018-05-21_reviews.csv.gz and barwon-south-west_2018-05-21_reviews.csv
# Downloaded barwon-south-west_2018-05-22_listings.csv.gz
# Removed invalid barwon-south-west_2018-05-22_listings.csv.gz and barwon-south-west_2018-05-22_listings.csv
# Downloaded barwon-south-west_2018-05-22_reviews.csv.gz
# Removed invalid barwon-south-west_2018-05-22_reviews.csv.gz and barwon-south-west_2018-05-22_reviews.csv
# Downloaded barwon-south-west_2018-05-23_listings.csv.gz
# Removed invalid barwon-south-west_2018-05-23_listings.csv.gz and barwon-south-west_2018-05-23_listings.csv
# Downloaded barwon-south-west_2018-05-23_reviews.csv.gz
# Removed invalid barwon-south-west_2018-05-23_reviews.csv.gz and barwon-south-west_2018-05-23_reviews.csv
# Downloaded barwon-south-west_2018-05-24_listings.csv.gz
# Removed invalid barwon-south-west_2018-05-24_listings.csv.gz and barwon-south-west_2018-05-24_listings.csv
# Downloaded barwon-south-west_2018-05-24_reviews.csv.gz
# Removed invalid barwon-south-west_2018-05-24_reviews.csv.gz and barwon-south-west_2018-05-24_reviews.csv
# Downloaded barwon-south-west_2018-05-25_listings.csv.gz
# Removed invalid barwon-south-west_2018-05-25_listings.csv.gz and barwon-south-west_2018-05-25_listings.csv
# Downloaded barwon-south-west_2018-05-25_reviews.csv.gz
# Removed invalid barwon-south-west_2018-05-25_reviews.csv.gz and barwon-south-west_2018-05-25_reviews.csv
# Downloaded barwon-south-west_2018-05-26_listings.csv.gz
# Removed invalid barwon-south-west_2018-05-26_listings.csv.gz and barwon-south-west_2018-05-26_listings.csv
# Downloaded barwon-south-west_2018-05-26_reviews.csv.gz
# Removed invalid barwon-south-west_2018-05-26_reviews.csv.gz and barwon-south-west_2018-05-26_reviews.csv
# Downloaded barwon-south-west_2018-05-27_listings.csv.gz
# Removed invalid barwon-south-west_2018-05-27_listings.csv.gz and barwon-south-west_2018-05-27_listings.csv
# Downloaded barwon-south-west_2018-05-27_reviews.csv.gz
# Removed invalid barwon-south-west_2018-05-27_reviews.csv.gz and barwon-south-west_2018-05-27_reviews.csv
# Downloaded barwon-south-west_2018-05-28_listings.csv.gz
# Removed invalid barwon-south-west_2018-05-28_listings.csv.gz and barwon-south-west_2018-05-28_listings.csv
# Downloaded barwon-south-west_2018-05-28_reviews.csv.gz
# Removed invalid barwon-south-west_2018-05-28_reviews.csv.gz and barwon-south-west_2018-05-28_reviews.csv
# Downloaded barwon-south-west_2018-05-29_listings.csv.gz
# Removed invalid barwon-south-west_2018-05-29_listings.csv.gz and barwon-south-west_2018-05-29_listings.csv
# Downloaded barwon-south-west_2018-05-29_reviews.csv.gz
# Removed invalid barwon-south-west_2018-05-29_reviews.csv.gz and barwon-south-west_2018-05-29_reviews.csv
# Downloaded barwon-south-west_2018-05-30_listings.csv.gz
# Removed invalid barwon-south-west_2018-05-30_listings.csv.gz and barwon-south-west_2018-05-30_listings.csv
# Downloaded barwon-south-west_2018-05-30_reviews.csv.gz
# Removed invalid barwon-south-west_2018-05-30_reviews.csv.gz and barwon-south-west_2018-05-30_reviews.csv
# Downloaded barwon-south-west_2018-05-31_listings.csv.gz
# Removed invalid barwon-south-west_2018-05-31_listings.csv.gz and barwon-south-west_2018-05-31_listings.csv
# Downloaded barwon-south-west_2018-05-31_reviews.csv.gz
# Removed invalid barwon-south-west_2018-05-31_reviews.csv.gz and barwon-south-west_2018-05-31_reviews.csv
# Downloaded barwon-south-west_2018-06-01_listings.csv.gz
# Removed invalid barwon-south-west_2018-06-01_listings.csv.gz and barwon-south-west_2018-06-01_listings.csv
# Downloaded barwon-south-west_2018-06-01_reviews.csv.gz
# Removed invalid barwon-south-west_2018-06-01_reviews.csv.gz and barwon-south-west_2018-06-01_reviews.csv
# Downloaded barwon-south-west_2018-06-02_listings.csv.gz
# Removed invalid barwon-south-west_2018-06-02_listings.csv.gz and barwon-south-west_2018-06-02_listings.csv
# Downloaded barwon-south-west_2018-06-02_reviews.csv.gz
# Removed invalid barwon-south-west_2018-06-02_reviews.csv.gz and barwon-south-west_2018-06-02_reviews.csv
# Downloaded barwon-south-west_2018-06-03_listings.csv.gz
# Removed invalid barwon-south-west_2018-06-03_listings.csv.gz and barwon-south-west_2018-06-03_listings.csv
# Downloaded barwon-south-west_2018-06-03_reviews.csv.gz
# Removed invalid barwon-south-west_2018-06-03_reviews.csv.gz and barwon-south-west_2018-06-03_reviews.csv
# Downloaded barwon-south-west_2018-06-04_listings.csv.gz
# Removed invalid barwon-south-west_2018-06-04_listings.csv.gz and barwon-south-west_2018-06-04_listings.csv
# Downloaded barwon-south-west_2018-06-04_reviews.csv.gz
# Removed invalid barwon-south-west_2018-06-04_reviews.csv.gz and barwon-south-west_2018-06-04_reviews.csv
# Downloaded barwon-south-west_2018-06-05_listings.csv.gz
# Removed invalid barwon-south-west_2018-06-05_listings.csv.gz and barwon-south-west_2018-06-05_listings.csv
# Downloaded barwon-south-west_2018-06-05_reviews.csv.gz
# Removed invalid barwon-south-west_2018-06-05_reviews.csv.gz and barwon-south-west_2018-06-05_reviews.csv
# Downloaded barwon-south-west_2018-06-06_listings.csv.gz
# Removed invalid barwon-south-west_2018-06-06_listings.csv.gz and barwon-south-west_2018-06-06_listings.csv
# Downloaded barwon-south-west_2018-06-06_reviews.csv.gz
# Removed invalid barwon-south-west_2018-06-06_reviews.csv.gz and barwon-south-west_2018-06-06_reviews.csv
# Downloaded barwon-south-west_2018-06-07_listings.csv.gz
# Removed invalid barwon-south-west_2018-06-07_listings.csv.gz and barwon-south-west_2018-06-07_listings.csv
# Downloaded barwon-south-west_2018-06-07_reviews.csv.gz
# Removed invalid barwon-south-west_2018-06-07_reviews.csv.gz and barwon-south-west_2018-06-07_reviews.csv
# Downloaded barwon-south-west_2018-06-08_listings.csv.gz
# Removed invalid barwon-south-west_2018-06-08_listings.csv.gz and barwon-south-west_2018-06-08_listings.csv
# Downloaded barwon-south-west_2018-06-08_reviews.csv.gz
# Removed invalid barwon-south-west_2018-06-08_reviews.csv.gz and barwon-south-west_2018-06-08_reviews.csv
# Downloaded barwon-south-west_2018-06-09_listings.csv.gz
# Removed invalid barwon-south-west_2018-06-09_listings.csv.gz and barwon-south-west_2018-06-09_listings.csv
# Downloaded barwon-south-west_2018-06-09_reviews.csv.gz
# Removed invalid barwon-south-west_2018-06-09_reviews.csv.gz and barwon-south-west_2018-06-09_reviews.csv
# Downloaded barwon-south-west_2018-06-10_listings.csv.gz
# Removed invalid barwon-south-west_2018-06-10_listings.csv.gz and barwon-south-west_2018-06-10_listings.csv
# Downloaded barwon-south-west_2018-06-10_reviews.csv.gz
# Removed invalid barwon-south-west_2018-06-10_reviews.csv.gz and barwon-south-west_2018-06-10_reviews.csv
# Downloaded barwon-south-west_2018-06-11_listings.csv.gz
# Removed invalid barwon-south-west_2018-06-11_listings.csv.gz and barwon-south-west_2018-06-11_listings.csv
# Downloaded barwon-south-west_2018-06-11_reviews.csv.gz
# Removed invalid barwon-south-west_2018-06-11_reviews.csv.gz and barwon-south-west_2018-06-11_reviews.csv
# Downloaded barwon-south-west_2018-06-12_listings.csv.gz
# Removed invalid barwon-south-west_2018-06-12_listings.csv.gz and barwon-south-west_2018-06-12_listings.csv
# Downloaded barwon-south-west_2018-06-12_reviews.csv.gz
# Removed invalid barwon-south-west_2018-06-12_reviews.csv.gz and barwon-south-west_2018-06-12_reviews.csv
# Downloaded barwon-south-west_2018-06-13_listings.csv.gz
# Removed invalid barwon-south-west_2018-06-13_listings.csv.gz and barwon-south-west_2018-06-13_listings.csv
# Downloaded barwon-south-west_2018-06-13_reviews.csv.gz
# Removed invalid barwon-south-west_2018-06-13_reviews.csv.gz and barwon-south-west_2018-06-13_reviews.csv
# Downloaded barwon-south-west_2018-06-14_listings.csv.gz
# Removed invalid barwon-south-west_2018-06-14_listings.csv.gz and barwon-south-west_2018-06-14_listings.csv
# Downloaded barwon-south-west_2018-06-14_reviews.csv.gz
# Removed invalid barwon-south-west_2018-06-14_reviews.csv.gz and barwon-south-west_2018-06-14_reviews.csv
# Downloaded barwon-south-west_2018-06-15_listings.csv.gz
# Removed invalid barwon-south-west_2018-06-15_listings.csv.gz and barwon-south-west_2018-06-15_listings.csv
# Downloaded barwon-south-west_2018-06-15_reviews.csv.gz
# Removed invalid barwon-south-west_2018-06-15_reviews.csv.gz and barwon-south-west_2018-06-15_reviews.csv
# Downloaded barwon-south-west_2018-06-16_listings.csv.gz
# Removed invalid barwon-south-west_2018-06-16_listings.csv.gz and barwon-south-west_2018-06-16_listings.csv
# Downloaded barwon-south-west_2018-06-16_reviews.csv.gz
# Removed invalid barwon-south-west_2018-06-16_reviews.csv.gz and barwon-south-west_2018-06-16_reviews.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 25
#      23 for affix in [affix_listings, affix_reviews]:
#      24     url = f'{prefix}/{location}/{date}/{affix}'
# ---> 25     res = requests.get(url)
#      26     # download .csv.gz files
#      27     name = f'{location.split('/')[-1]}_{date}_{affix.split('/')[-1]}'
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/site-packages/requests/api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/site-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/site-packages/requests/sessions.py:542, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     537 send_kwargs = {
#     538     'timeout': timeout,
#     539     'allow_redirects': allow_redirects,
#     540 }
#     541 send_kwargs.update(settings)
# --> 542 resp = self.send(prep, **send_kwargs)
#     544 return resp
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/site-packages/requests/sessions.py:655, in Session.send(self, request, **kwargs)
#     652 start = preferred_clock()
#     654 # Send the request
# --> 655 r = adapter.send(request, **kwargs)
#     657 # Total elapsed time of the request (approximately)
#     658 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/site-packages/requests/adapters.py:439, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     437 try:
#     438     if not chunked:
# --> 439         resp = conn.urlopen(
#     440             method=request.method,
#     441             url=url,
#     442             body=request.body,
#     443             headers=request.headers,
#     444             redirect=False,
#     445             assert_same_host=False,
#     446             preload_content=False,
#     447             decode_content=False,
#     448             retries=self.max_retries,
#     449             timeout=timeout
#     450         )
#     452     # Send the request.
#     453     else:
#     454         if hasattr(conn, 'proxy_pool'):
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/site-packages/urllib3/connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#     729 response_conn = conn if not release_conn else None
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462             httplib_response = conn.getresponse()
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     469     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/site-packages/urllib3/connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459 except TypeError:
#     460     # Python 3
#     461     try:
# --> 462         httplib_response = conn.getresponse()
#     463     except BaseException as e:
#     464         # Remove the TypeError from the exception chain in
#     465         # Python 3 (including for exceptions like SystemExit).
#     466         # Otherwise it looks like a bug in the code.
#     467         six.raise_from(e, None)
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/socket.py:708, in SocketIO.readinto(self, b)
#     706 while True:
#     707     try:
# --> 708         return self._sock.recv_into(b)
#     709     except timeout:
#     710         self._timeout_occurred = True
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/data_scraping/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:
